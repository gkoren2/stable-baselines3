# %% [markdown]
# <a href="https://colab.research.google.com/github/araffin/rl-tutorial-jnrr19/blob/sb3/4_callbacks_hyperparameter_tuning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Stable Baselines3 Tutorial - Callbacks and hyperparameter tuning
#
# Github repo: https://github.com/araffin/rl-tutorial-jnrr19/tree/sb3/
#
# Stable-Baselines3: https://github.com/DLR-RM/stable-baselines3
#
# Documentation: https://stable-baselines3.readthedocs.io/en/master/
#
# RL Baselines3 zoo: https://github.com/DLR-RM/rl-baselines3-zoo
#
#
# ## Introduction
#
# In this notebook, you will learn how to use [Callbacks](https://stable-baselines3.readthedocs.io/en/master/guide/callbacks.html) which allow to do monitoring, auto saving, model manipulation, progress bars, ...
#
#
# You will also see that finding good hyperparameters is key to success in RL.
#
# ## Install Dependencies and Stable Baselines3 Using Pip

# %%
# !apt install swig
# !pip install tqdm==4.36.1
# !pip install stable-baselines3[extra]

# %%
import os
import sys
path_to_curr_file=os.path.realpath(os.getcwd())
proj_root=os.path.dirname(os.path.dirname(path_to_curr_file))
if proj_root not in sys.path:
    sys.path.insert(0,proj_root)
import stable_baselines3
stable_baselines3.__version__
# Out:
# '0.11.0a0'

# %%
import gym
from stable_baselines3 import A2C, SAC, PPO, TD3

# %% [markdown]
# # The importance of hyperparameter tuning
#
# When compared with Supervised Learning, Deep Reinforcement Learning is far more sensitive to the choice of hyper-parameters such as learning rate, number of neurons, number of layers, optimizer ... etc.
# Poor choice of hyper-parameters can lead to poor/unstable convergence. This challenge is compounded by the variability in performance across random seeds (used to initialize the network weights and the environment).
#
# Here we demonstrate on a toy example the [Soft Actor Critic](https://arxiv.org/abs/1801.01290) algorithm applied in the Pendulum environment. Note the change in performance between the default and "tuned" parameters.

# %%
import numpy as np

from stable_baselines3.common.evaluation import evaluate_policy

# %%
eval_env = gym.make('Pendulum-v0')

# %%
default_model = SAC('MlpPolicy', 'Pendulum-v0', verbose=1, seed=0, batch_size=64, policy_kwargs=dict(net_arch=[64, 64])).learn(8000)
# Out:
# Using cuda device
# Creating environment from the given name 'Pendulum-v0'
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.48e+03 |
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 61        |
# |    time_elapsed    | 12        |
# |    total timesteps | 800       |
# | train/             |           |
# |    actor_loss      | 20.8      |
# |    critic_loss     | 0.802     |
# |    ent_coef        | 0.814     |
# |    ent_coef_loss   | -0.336    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 699       |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.62e+03 |
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 58        |
# |    time_elapsed    | 27        |
# |    total timesteps | 1600      |
# | train/             |           |
# |    actor_loss      | 45.5      |
# |    critic_loss     | 26.9      |
# |    ent_coef        | 0.645     |
# |    ent_coef_loss   | -0.634    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 1499      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.58e+03 |
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 57        |
# |    time_elapsed    | 41        |
# |    total timesteps | 2400      |
# | train/             |           |
# |    actor_loss      | 75.1      |
# |    critic_loss     | 77        |
# |    ent_coef        | 0.515     |
# |    ent_coef_loss   | -0.853    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2299      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.51e+03 |
# | time/              |           |
# |    episodes        | 16        |
# |    fps             | 56        |
# |    time_elapsed    | 56        |
# |    total timesteps | 3200      |
# | train/             |           |
# |    actor_loss      | 96.1      |
# |    critic_loss     | 144       |
# |    ent_coef        | 0.419     |
# |    ent_coef_loss   | -1.1      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3099      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.43e+03 |
# | time/              |           |
# |    episodes        | 20        |
# |    fps             | 56        |
# |    time_elapsed    | 71        |
# |    total timesteps | 4000      |
# | train/             |           |
# |    actor_loss      | 112       |
# |    critic_loss     | 4.99      |
# |    ent_coef        | 0.343     |
# |    ent_coef_loss   | -0.81     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3899      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.38e+03 |
# | time/              |           |
# |    episodes        | 24        |
# |    fps             | 55        |
# |    time_elapsed    | 86        |
# |    total timesteps | 4800      |
# | train/             |           |
# |    actor_loss      | 132       |
# |    critic_loss     | 4.37      |
# |    ent_coef        | 0.283     |
# |    ent_coef_loss   | -1.01     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 4699      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.34e+03 |
# | time/              |           |
# |    episodes        | 28        |
# |    fps             | 55        |
# |    time_elapsed    | 101       |
# |    total timesteps | 5600      |
# | train/             |           |
# |    actor_loss      | 138       |
# |    critic_loss     | 8.33      |
# |    ent_coef        | 0.237     |
# |    ent_coef_loss   | -0.791    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 5499      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.32e+03 |
# | time/              |           |
# |    episodes        | 32        |
# |    fps             | 55        |
# |    time_elapsed    | 116       |
# |    total timesteps | 6400      |
# | train/             |           |
# |    actor_loss      | 151       |
# |    critic_loss     | 7.86      |
# |    ent_coef        | 0.201     |
# |    ent_coef_loss   | -0.208    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 6299      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.28e+03 |
# | time/              |           |
# |    episodes        | 36        |
# |    fps             | 54        |
# |    time_elapsed    | 131       |
# |    total timesteps | 7200      |
# | train/             |           |
# |    actor_loss      | 173       |
# |    critic_loss     | 9.56      |
# |    ent_coef        | 0.184     |
# |    ent_coef_loss   | 0.0332    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 7099      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.24e+03 |
# | time/              |           |
# |    episodes        | 40        |
# |    fps             | 54        |
# |    time_elapsed    | 145       |
# |    total timesteps | 8000      |
# | train/             |           |
# |    actor_loss      | 174       |
# |    critic_loss     | 8.7       |
# |    ent_coef        | 0.182     |
# |    ent_coef_loss   | 0.275     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 7899      |
# ----------------------------------

# %%
mean_reward, std_reward = evaluate_policy(default_model, eval_env, n_eval_episodes=100)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# mean_reward:-904.48 +/- 53.86

# %%
tuned_model = SAC('MlpPolicy', 'Pendulum-v0', batch_size=256, verbose=1, policy_kwargs=dict(net_arch=[256, 256]), seed=0).learn(8000)
# Out:
# Using cuda device
# Creating environment from the given name 'Pendulum-v0'
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.46e+03 |
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 67        |
# |    time_elapsed    | 11        |
# |    total timesteps | 800       |
# | train/             |           |
# |    actor_loss      | 24.6      |
# |    critic_loss     | 1.95      |
# |    ent_coef        | 0.813     |
# |    ent_coef_loss   | -0.336    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 699       |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.57e+03 |
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 59        |
# |    time_elapsed    | 26        |
# |    total timesteps | 1600      |
# | train/             |           |
# |    actor_loss      | 52.2      |
# |    critic_loss     | 9.23      |
# |    ent_coef        | 0.645     |
# |    ent_coef_loss   | -0.637    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 1499      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.42e+03 |
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 57        |
# |    time_elapsed    | 41        |
# |    total timesteps | 2400      |
# | train/             |           |
# |    actor_loss      | 71.3      |
# |    critic_loss     | 1.35      |
# |    ent_coef        | 0.526     |
# |    ent_coef_loss   | -0.729    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2299      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.32e+03 |
# | time/              |           |
# |    episodes        | 16        |
# |    fps             | 56        |
# |    time_elapsed    | 56        |
# |    total timesteps | 3200      |
# | train/             |           |
# |    actor_loss      | 84.7      |
# |    critic_loss     | 104       |
# |    ent_coef        | 0.444     |
# |    ent_coef_loss   | -0.611    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3099      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.23e+03 |
# | time/              |           |
# |    episodes        | 20        |
# |    fps             | 56        |
# |    time_elapsed    | 71        |
# |    total timesteps | 4000      |
# | train/             |           |
# |    actor_loss      | 93.6      |
# |    critic_loss     | 4.75      |
# |    ent_coef        | 0.386     |
# |    ent_coef_loss   | -0.178    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3899      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.13e+03 |
# | time/              |           |
# |    episodes        | 24        |
# |    fps             | 55        |
# |    time_elapsed    | 85        |
# |    total timesteps | 4800      |
# | train/             |           |
# |    actor_loss      | 109       |
# |    critic_loss     | 3.48      |
# |    ent_coef        | 0.345     |
# |    ent_coef_loss   | -0.239    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 4699      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.05e+03 |
# | time/              |           |
# |    episodes        | 28        |
# |    fps             | 55        |
# |    time_elapsed    | 101       |
# |    total timesteps | 5600      |
# | train/             |           |
# |    actor_loss      | 109       |
# |    critic_loss     | 223       |
# |    ent_coef        | 0.311     |
# |    ent_coef_loss   | -0.466    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 5499      |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | -969     |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 55       |
# |    time_elapsed    | 115      |
# |    total timesteps | 6400     |
# | train/             |          |
# |    actor_loss      | 120      |
# |    critic_loss     | 4.5      |
# |    ent_coef        | 0.295    |
# |    ent_coef_loss   | 0.00297  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6299     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | -890     |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 54       |
# |    time_elapsed    | 130      |
# |    total timesteps | 7200     |
# | train/             |          |
# |    actor_loss      | 116      |
# |    critic_loss     | 82.9     |
# |    ent_coef        | 0.303    |
# |    ent_coef_loss   | 0.261    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | -826     |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 54       |
# |    time_elapsed    | 145      |
# |    total timesteps | 8000     |
# | train/             |          |
# |    actor_loss      | 115      |
# |    critic_loss     | 180      |
# |    ent_coef        | 0.307    |
# |    ent_coef_loss   | 0.0308   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7899     |
# ---------------------------------

# %%
mean_reward, std_reward = evaluate_policy(tuned_model, eval_env, n_eval_episodes=100)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# mean_reward:-215.46 +/- 128.83

# %% [markdown]
# Exploring hyperparameter tuning is out of the scope (and time schedule) of this tutorial. However, you need to know that we provide tuned hyperparameter in the [rl zoo](https://github.com/DLR-RM/rl-baselines3-zoo) as well as automatic hyperparameter optimization using [Optuna](https://github.com/pfnet/optuna).

# %% [markdown]
# # Callbacks
#
#
# Please read the [documentation](https://stable-baselines3.readthedocs.io/en/master/guide/callbacks.html). Although Stable-Baselines3 provides you with a callback collection (e.g. for creating checkpoints or for evaluation), we are going to re-implement some so you can get a good understanding of how they work.
#
# To build a custom callback, you need to create a class that derives from `BaseCallback`. This will give you access to events (`_on_training_start`, `_on_step()`) and useful variables (like `self.model` for the RL model).
#
# `_on_step` returns a boolean value for whether or not the training should continue.
#
# Thanks to the access to the models variables, in particular `self.model`, we are able to even change the parameters of the model without halting the training, or changing the model's code.

# %%
from stable_baselines3.common.callbacks import BaseCallback

# %%
class CustomCallback(BaseCallback):
    """
    A custom callback that derives from ``BaseCallback``.

    :param verbose: (int) Verbosity level 0: not output 1: info 2: debug
    """
    def __init__(self, verbose=0):
        super(CustomCallback, self).__init__(verbose)
        # Those variables will be accessible in the callback
        # (they are defined in the base class)
        # The RL model
        # self.model = None  # type: BaseRLModel
        # An alias for self.model.get_env(), the environment used for training
        # self.training_env = None  # type: Union[gym.Env, VecEnv, None]
        # Number of time the callback was called
        # self.n_calls = 0  # type: int
        # self.num_timesteps = 0  # type: int
        # local and global variables
        # self.locals = None  # type: Dict[str, Any]
        # self.globals = None  # type: Dict[str, Any]
        # The logger object, used to report things in the terminal
        # self.logger = None  # type: logger.Logger
        # # Sometimes, for event callback, it is useful
        # # to have access to the parent object
        # self.parent = None  # type: Optional[BaseCallback]

    def _on_training_start(self) -> None:
        """
        This method is called before the first rollout starts.
        """
        pass

    def _on_rollout_start(self) -> None:
        """
        A rollout is the collection of environment interaction
        using the current policy.
        This event is triggered before collecting new samples.
        """
        pass

    def _on_step(self) -> bool:
        """
        This method will be called by the model after each call to `env.step()`.

        For child callback (of an `EventCallback`), this will be called
        when the event is triggered.

        :return: (bool) If the callback returns False, training is aborted early.
        """
        return True

    def _on_rollout_end(self) -> None:
        """
        This event is triggered before updating the policy.
        """
        pass

    def _on_training_end(self) -> None:
        """
        This event is triggered before exiting the `learn()` method.
        """
        pass

# %% [markdown]
# Here we have a simple callback that can only be called twice:

# %%
class SimpleCallback(BaseCallback):
    """
    a simple callback that can only be called twice

    :param verbose: (int) Verbosity level 0: not output 1: info 2: debug
    """
    def __init__(self, verbose=0):
        super(SimpleCallback, self).__init__(verbose)
        self._called = False
    
    def _on_step(self):
        if not self._called:
            print("callback - first call")
            self._called = True
            return True # returns True, training continues.
        print("callback - second call")
        return False # returns False, training stops.

# %%
model = SAC('MlpPolicy', 'Pendulum-v0', verbose=1)
model.learn(8000, callback=SimpleCallback())
# Out:
# Using cuda device
# Creating environment from the given name 'Pendulum-v0'
# Wrapping the env in a DummyVecEnv.
# callback - first call
# callback - second call

# %% [markdown]
# ## First example: Auto saving best model
# In RL, it is quite useful to keep a clean version of a model as you are training, as we can end up with burn-in of a bad policy. This is a typical use case for callback, as they can call the save function of the model, and observe the training over time.
#
# Using the monitoring wrapper, we can save statistics of the environment, and use them to determine the mean training reward.
# This allows us to save the best model while training.
#
# Note that this is not the proper way of evaluating an RL agent, you should create an test environment and evaluate the agent performance in the callback (cf `EvalCallback`). For simplicity, we will be using the training reward as a proxy.

# %%
import os

import numpy as np

from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.results_plotter import load_results, ts2xy

# %%
class SaveOnBestTrainingRewardCallback(BaseCallback):
    """
    Callback for saving a model (the check is done every ``check_freq`` steps)
    based on the training reward (in practice, we recommend using ``EvalCallback``).

    :param check_freq: (int)
    :param log_dir: (str) Path to the folder where the model will be saved.
      It must contains the file created by the ``Monitor`` wrapper.
    :param verbose: (int)
    """
    def __init__(self, check_freq, log_dir, verbose=1):
        super(SaveOnBestTrainingRewardCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.log_dir = log_dir
        self.save_path = os.path.join(log_dir, 'best_model')
        self.best_mean_reward = -np.inf

    def _init_callback(self) -> None:
        # Create folder if needed
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self) -> bool:
        if self.n_calls % self.check_freq == 0:

            # Retrieve training reward
            x, y = ts2xy(load_results(self.log_dir), 'timesteps')
            if len(x) > 0:
                # Mean training reward over the last 100 episodes
                mean_reward = np.mean(y[-100:])
                if self.verbose > 0:
                    print("Num timesteps: {}".format(self.num_timesteps))
                    print("Best mean reward: {:.2f} - Last mean reward per episode: {:.2f}".format(self.best_mean_reward, mean_reward))

                # New best model, you could save the agent here
                if mean_reward > self.best_mean_reward:
                    self.best_mean_reward = mean_reward
                    # Example for saving best model
                    if self.verbose > 0:
                        print("Saving new best model at {} timesteps".format(x[-1]))
                        print("Saving new best model to {}.zip".format(self.save_path))
                    self.model.save(self.save_path)
        return True

# %%
# Create log dir
log_dir = os.path.join(os.path.expanduser('~'),'share','Data','study','sbl3','tmp/gym/')
os.makedirs(log_dir, exist_ok=True)

# Create and wrap the environment
env = make_vec_env('CartPole-v1', n_envs=1, monitor_dir=log_dir)
# it is equivalent to:
# env = gym.make('CartPole-v1')
# env = Monitor(env, log_dir)
# env = DummyVecEnv([lambda: env])

# Create Callback
callback = SaveOnBestTrainingRewardCallback(check_freq=20, log_dir=log_dir, verbose=1)

model = A2C('MlpPolicy', env, verbose=0)
model.learn(total_timesteps=10000, callback=callback)
# Out:
# Num timesteps: 20
# Best mean reward: -inf - Last mean reward per episode: 18.00
# Saving new best model at 18 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 40
# Best mean reward: 18.00 - Last mean reward per episode: 14.50
# Num timesteps: 60
# Best mean reward: 18.00 - Last mean reward per episode: 14.50
# Num timesteps: 80
# Best mean reward: 18.00 - Last mean reward per episode: 14.50
# Num timesteps: 100
# Best mean reward: 18.00 - Last mean reward per episode: 17.00
# Num timesteps: 120
# Best mean reward: 18.00 - Last mean reward per episode: 18.50
# Saving new best model at 111 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 140
# Best mean reward: 18.50 - Last mean reward per episode: 18.50
# Num timesteps: 160
# Best mean reward: 18.50 - Last mean reward per episode: 20.86
# Saving new best model at 146 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 180
# Best mean reward: 20.86 - Last mean reward per episode: 20.88
# Saving new best model at 167 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 200
# Best mean reward: 20.88 - Last mean reward per episode: 20.89
# Saving new best model at 188 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 220
# Best mean reward: 20.89 - Last mean reward per episode: 20.30
# Num timesteps: 240
# Best mean reward: 20.89 - Last mean reward per episode: 21.64
# Saving new best model at 238 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 260
# Best mean reward: 21.64 - Last mean reward per episode: 21.33
# Num timesteps: 280
# Best mean reward: 21.64 - Last mean reward per episode: 19.57
# Num timesteps: 300
# Best mean reward: 21.64 - Last mean reward per episode: 19.93
# Num timesteps: 320
# Best mean reward: 21.64 - Last mean reward per episode: 19.93
# Num timesteps: 340
# Best mean reward: 21.64 - Last mean reward per episode: 19.93
# Num timesteps: 360
# Best mean reward: 21.64 - Last mean reward per episode: 21.00
# Num timesteps: 380
# Best mean reward: 21.64 - Last mean reward per episode: 19.89
# Num timesteps: 400
# Best mean reward: 21.64 - Last mean reward per episode: 19.50
# Num timesteps: 420
# Best mean reward: 21.64 - Last mean reward per episode: 19.86
# Num timesteps: 440
# Best mean reward: 21.64 - Last mean reward per episode: 19.55
# Num timesteps: 460
# Best mean reward: 21.64 - Last mean reward per episode: 19.39
# Num timesteps: 480
# Best mean reward: 21.64 - Last mean reward per episode: 19.39
# Num timesteps: 500
# Best mean reward: 21.64 - Last mean reward per episode: 20.08
# Num timesteps: 520
# Best mean reward: 21.64 - Last mean reward per episode: 19.96
# Num timesteps: 540
# Best mean reward: 21.64 - Last mean reward per episode: 19.78
# Num timesteps: 560
# Best mean reward: 21.64 - Last mean reward per episode: 19.86
# Num timesteps: 580
# Best mean reward: 21.64 - Last mean reward per episode: 19.66
# Num timesteps: 600
# Best mean reward: 21.64 - Last mean reward per episode: 19.67
# Num timesteps: 620
# Best mean reward: 21.64 - Last mean reward per episode: 19.67
# Num timesteps: 640
# Best mean reward: 21.64 - Last mean reward per episode: 19.67
# Num timesteps: 660
# Best mean reward: 21.64 - Last mean reward per episode: 20.38
# Num timesteps: 680
# Best mean reward: 21.64 - Last mean reward per episode: 20.38
# Num timesteps: 700
# Best mean reward: 21.64 - Last mean reward per episode: 20.38
# Num timesteps: 720
# Best mean reward: 21.64 - Last mean reward per episode: 21.27
# Num timesteps: 740
# Best mean reward: 21.64 - Last mean reward per episode: 21.26
# Num timesteps: 760
# Best mean reward: 21.64 - Last mean reward per episode: 21.54
# Num timesteps: 780
# Best mean reward: 21.64 - Last mean reward per episode: 21.54
# Num timesteps: 800
# Best mean reward: 21.64 - Last mean reward per episode: 21.97
# Saving new best model at 791 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 820
# Best mean reward: 21.97 - Last mean reward per episode: 22.16
# Saving new best model at 820 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 840
# Best mean reward: 22.16 - Last mean reward per episode: 22.08
# Num timesteps: 860
# Best mean reward: 22.16 - Last mean reward per episode: 22.08
# Num timesteps: 880
# Best mean reward: 22.16 - Last mean reward per episode: 22.54
# Saving new best model at 879 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 900
# Best mean reward: 22.54 - Last mean reward per episode: 22.38
# Num timesteps: 920
# Best mean reward: 22.54 - Last mean reward per episode: 22.38
# Num timesteps: 940
# Best mean reward: 22.54 - Last mean reward per episode: 22.17
# Num timesteps: 960
# Best mean reward: 22.54 - Last mean reward per episode: 22.07
# Num timesteps: 980
# Best mean reward: 22.54 - Last mean reward per episode: 22.27
# Num timesteps: 1000
# Best mean reward: 22.54 - Last mean reward per episode: 22.27
# Num timesteps: 1020
# Best mean reward: 22.54 - Last mean reward per episode: 22.27
# Num timesteps: 1040
# Best mean reward: 22.54 - Last mean reward per episode: 22.61
# Saving new best model at 1040 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 1060
# Best mean reward: 22.61 - Last mean reward per episode: 22.61
# Num timesteps: 1080
# Best mean reward: 22.61 - Last mean reward per episode: 22.98
# Saving new best model at 1080 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 1100
# Best mean reward: 22.98 - Last mean reward per episode: 22.75
# Num timesteps: 1120
# Best mean reward: 22.98 - Last mean reward per episode: 22.57
# Num timesteps: 1140
# Best mean reward: 22.98 - Last mean reward per episode: 22.58
# Num timesteps: 1160
# Best mean reward: 22.98 - Last mean reward per episode: 22.53
# Num timesteps: 1180
# Best mean reward: 22.98 - Last mean reward per episode: 22.33
# Num timesteps: 1200
# Best mean reward: 22.98 - Last mean reward per episode: 22.33
# Num timesteps: 1220
# Best mean reward: 22.98 - Last mean reward per episode: 22.83
# Num timesteps: 1240
# Best mean reward: 22.98 - Last mean reward per episode: 22.76
# Num timesteps: 1260
# Best mean reward: 22.98 - Last mean reward per episode: 22.91
# Num timesteps: 1280
# Best mean reward: 22.98 - Last mean reward per episode: 22.91
# Num timesteps: 1300
# Best mean reward: 22.98 - Last mean reward per episode: 22.91
# Num timesteps: 1320
# Best mean reward: 22.98 - Last mean reward per episode: 23.30
# Saving new best model at 1305 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 1340
# Best mean reward: 23.30 - Last mean reward per episode: 23.07
# Num timesteps: 1360
# Best mean reward: 23.30 - Last mean reward per episode: 22.90
# Num timesteps: 1380
# Best mean reward: 23.30 - Last mean reward per episode: 22.78
# Num timesteps: 1400
# Best mean reward: 23.30 - Last mean reward per episode: 22.78
# Num timesteps: 1420
# Best mean reward: 23.30 - Last mean reward per episode: 23.13
# Num timesteps: 1440
# Best mean reward: 23.30 - Last mean reward per episode: 23.13
# Num timesteps: 1460
# Best mean reward: 23.30 - Last mean reward per episode: 23.08
# Num timesteps: 1480
# Best mean reward: 23.30 - Last mean reward per episode: 23.08
# Num timesteps: 1500
# Best mean reward: 23.30 - Last mean reward per episode: 23.14
# Num timesteps: 1520
# Best mean reward: 23.30 - Last mean reward per episode: 23.26
# Num timesteps: 1540
# Best mean reward: 23.30 - Last mean reward per episode: 23.26
# Num timesteps: 1560
# Best mean reward: 23.30 - Last mean reward per episode: 23.27
# Num timesteps: 1580
# Best mean reward: 23.30 - Last mean reward per episode: 23.27
# Num timesteps: 1600
# Best mean reward: 23.30 - Last mean reward per episode: 23.25
# Num timesteps: 1620
# Best mean reward: 23.30 - Last mean reward per episode: 23.25
# Num timesteps: 1640
# Best mean reward: 23.30 - Last mean reward per episode: 23.25
# Num timesteps: 1660
# Best mean reward: 23.30 - Last mean reward per episode: 23.25
# Num timesteps: 1680
# Best mean reward: 23.30 - Last mean reward per episode: 24.10
# Saving new best model at 1663 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 1700
# Best mean reward: 24.10 - Last mean reward per episode: 24.01
# Num timesteps: 1720
# Best mean reward: 24.10 - Last mean reward per episode: 23.85
# Num timesteps: 1740
# Best mean reward: 24.10 - Last mean reward per episode: 23.85
# Num timesteps: 1760
# Best mean reward: 24.10 - Last mean reward per episode: 23.85
# Num timesteps: 1780
# Best mean reward: 24.10 - Last mean reward per episode: 24.26
# Saving new best model at 1771 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 1800
# Best mean reward: 24.26 - Last mean reward per episode: 23.96
# Num timesteps: 1820
# Best mean reward: 24.26 - Last mean reward per episode: 23.80
# Num timesteps: 1840
# Best mean reward: 24.26 - Last mean reward per episode: 23.80
# Num timesteps: 1860
# Best mean reward: 24.26 - Last mean reward per episode: 24.06
# Num timesteps: 1880
# Best mean reward: 24.26 - Last mean reward per episode: 24.09
# Num timesteps: 1900
# Best mean reward: 24.26 - Last mean reward per episode: 23.99
# Num timesteps: 1920
# Best mean reward: 24.26 - Last mean reward per episode: 23.99
# Num timesteps: 1940
# Best mean reward: 24.26 - Last mean reward per episode: 23.99
# Num timesteps: 1960
# Best mean reward: 24.26 - Last mean reward per episode: 24.38
# Saving new best model at 1950 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 1980
# Best mean reward: 24.38 - Last mean reward per episode: 24.35
# Num timesteps: 2000
# Best mean reward: 24.38 - Last mean reward per episode: 24.18
# Num timesteps: 2020
# Best mean reward: 24.38 - Last mean reward per episode: 24.18
# Num timesteps: 2040
# Best mean reward: 24.38 - Last mean reward per episode: 24.18
# Num timesteps: 2060
# Best mean reward: 24.38 - Last mean reward per episode: 24.72
# Saving new best model at 2052 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 2080
# Best mean reward: 24.72 - Last mean reward per episode: 24.72
# Num timesteps: 2100
# Best mean reward: 24.72 - Last mean reward per episode: 24.94
# Saving new best model at 2095 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 2120
# Best mean reward: 24.94 - Last mean reward per episode: 24.94
# Num timesteps: 2140
# Best mean reward: 24.94 - Last mean reward per episode: 24.94
# Num timesteps: 2160
# Best mean reward: 24.94 - Last mean reward per episode: 25.24
# Saving new best model at 2145 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 2180
# Best mean reward: 25.24 - Last mean reward per episode: 25.20
# Num timesteps: 2200
# Best mean reward: 25.24 - Last mean reward per episode: 25.20
# Num timesteps: 2220
# Best mean reward: 25.24 - Last mean reward per episode: 25.45
# Saving new best model at 2214 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 2240
# Best mean reward: 25.45 - Last mean reward per episode: 25.45
# Num timesteps: 2260
# Best mean reward: 25.45 - Last mean reward per episode: 25.45
# Num timesteps: 2280
# Best mean reward: 25.45 - Last mean reward per episode: 25.56
# Saving new best model at 2275 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 2300
# Best mean reward: 25.56 - Last mean reward per episode: 25.56
# Num timesteps: 2320
# Best mean reward: 25.56 - Last mean reward per episode: 25.56
# Num timesteps: 2340
# Best mean reward: 25.56 - Last mean reward per episode: 25.42
# Num timesteps: 2360
# Best mean reward: 25.56 - Last mean reward per episode: 25.42
# Num timesteps: 2380
# Best mean reward: 25.56 - Last mean reward per episode: 25.49
# Num timesteps: 2400
# Best mean reward: 25.56 - Last mean reward per episode: 25.49
# Num timesteps: 2420
# Best mean reward: 25.56 - Last mean reward per episode: 25.66
# Saving new best model at 2412 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 2440
# Best mean reward: 25.66 - Last mean reward per episode: 25.66
# Num timesteps: 2460
# Best mean reward: 25.66 - Last mean reward per episode: 25.62
# Num timesteps: 2480
# Best mean reward: 25.66 - Last mean reward per episode: 25.55
# Num timesteps: 2500
# Best mean reward: 25.66 - Last mean reward per episode: 25.51
# Num timesteps: 2520
# Best mean reward: 25.66 - Last mean reward per episode: 25.44
# Num timesteps: 2540
# Best mean reward: 25.66 - Last mean reward per episode: 25.37
# Num timesteps: 2560
# Best mean reward: 25.66 - Last mean reward per episode: 25.39
# Num timesteps: 2580
# Best mean reward: 25.66 - Last mean reward per episode: 25.39
# Num timesteps: 2600
# Best mean reward: 25.66 - Last mean reward per episode: 25.69
# Saving new best model at 2598 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 2620
# Best mean reward: 25.69 - Last mean reward per episode: 25.69
# Num timesteps: 2640
# Best mean reward: 25.69 - Last mean reward per episode: 25.69
# Num timesteps: 2660
# Best mean reward: 25.69 - Last mean reward per episode: 25.98
# Saving new best model at 2644 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 2680
# Best mean reward: 25.98 - Last mean reward per episode: 26.04
# Saving new best model at 2662 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 2700
# Best mean reward: 26.04 - Last mean reward per episode: 26.04
# Num timesteps: 2720
# Best mean reward: 26.04 - Last mean reward per episode: 26.16
# Saving new best model at 2701 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 2740
# Best mean reward: 26.16 - Last mean reward per episode: 26.12
# Num timesteps: 2760
# Best mean reward: 26.16 - Last mean reward per episode: 26.07
# Num timesteps: 2780
# Best mean reward: 26.16 - Last mean reward per episode: 26.07
# Num timesteps: 2800
# Best mean reward: 26.16 - Last mean reward per episode: 26.07
# Num timesteps: 2820
# Best mean reward: 26.16 - Last mean reward per episode: 26.45
# Saving new best model at 2812 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 2840
# Best mean reward: 26.45 - Last mean reward per episode: 26.45
# Num timesteps: 2860
# Best mean reward: 26.45 - Last mean reward per episode: 26.54
# Saving new best model at 2842 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 2880
# Best mean reward: 26.54 - Last mean reward per episode: 26.67
# Saving new best model at 2870 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 2900
# Best mean reward: 26.67 - Last mean reward per episode: 26.58
# Num timesteps: 2920
# Best mean reward: 26.67 - Last mean reward per episode: 26.58
# Num timesteps: 2940
# Best mean reward: 26.67 - Last mean reward per episode: 26.68
# Saving new best model at 2924 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 2960
# Best mean reward: 26.68 - Last mean reward per episode: 26.77
# Saving new best model at 2943 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 2980
# Best mean reward: 26.77 - Last mean reward per episode: 26.77
# Num timesteps: 3000
# Best mean reward: 26.77 - Last mean reward per episode: 26.77
# Num timesteps: 3020
# Best mean reward: 26.77 - Last mean reward per episode: 27.19
# Saving new best model at 3018 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 3040
# Best mean reward: 27.19 - Last mean reward per episode: 27.19
# Num timesteps: 3060
# Best mean reward: 27.19 - Last mean reward per episode: 27.19
# Num timesteps: 3080
# Best mean reward: 27.19 - Last mean reward per episode: 27.35
# Saving new best model at 3077 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 3100
# Best mean reward: 27.35 - Last mean reward per episode: 27.35
# Num timesteps: 3120
# Best mean reward: 27.35 - Last mean reward per episode: 27.48
# Saving new best model at 3105 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 3140
# Best mean reward: 27.48 - Last mean reward per episode: 27.48
# Num timesteps: 3160
# Best mean reward: 27.48 - Last mean reward per episode: 27.48
# Num timesteps: 3180
# Best mean reward: 27.48 - Last mean reward per episode: 28.10
# Saving new best model at 3178 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 3200
# Best mean reward: 28.10 - Last mean reward per episode: 28.21
# Saving new best model at 3199 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 3220
# Best mean reward: 28.21 - Last mean reward per episode: 28.21
# Num timesteps: 3240
# Best mean reward: 28.21 - Last mean reward per episode: 28.21
# Num timesteps: 3260
# Best mean reward: 28.21 - Last mean reward per episode: 28.21
# Num timesteps: 3280
# Best mean reward: 28.21 - Last mean reward per episode: 28.87
# Saving new best model at 3277 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 3300
# Best mean reward: 28.87 - Last mean reward per episode: 28.87
# Num timesteps: 3320
# Best mean reward: 28.87 - Last mean reward per episode: 28.88
# Saving new best model at 3305 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 3340
# Best mean reward: 28.88 - Last mean reward per episode: 28.98
# Saving new best model at 3328 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 3360
# Best mean reward: 28.98 - Last mean reward per episode: 28.98
# Num timesteps: 3380
# Best mean reward: 28.98 - Last mean reward per episode: 28.98
# Num timesteps: 3400
# Best mean reward: 28.98 - Last mean reward per episode: 28.98
# Num timesteps: 3420
# Best mean reward: 28.98 - Last mean reward per episode: 29.58
# Saving new best model at 3404 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 3440
# Best mean reward: 29.58 - Last mean reward per episode: 29.58
# Num timesteps: 3460
# Best mean reward: 29.58 - Last mean reward per episode: 29.66
# Saving new best model at 3448 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 3480
# Best mean reward: 29.66 - Last mean reward per episode: 29.69
# Saving new best model at 3473 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 3500
# Best mean reward: 29.69 - Last mean reward per episode: 29.69
# Num timesteps: 3520
# Best mean reward: 29.69 - Last mean reward per episode: 29.83
# Saving new best model at 3502 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 3540
# Best mean reward: 29.83 - Last mean reward per episode: 29.83
# Num timesteps: 3560
# Best mean reward: 29.83 - Last mean reward per episode: 29.83
# Num timesteps: 3580
# Best mean reward: 29.83 - Last mean reward per episode: 29.83
# Num timesteps: 3600
# Best mean reward: 29.83 - Last mean reward per episode: 30.47
# Saving new best model at 3581 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 3620
# Best mean reward: 30.47 - Last mean reward per episode: 30.51
# Saving new best model at 3607 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 3640
# Best mean reward: 30.51 - Last mean reward per episode: 30.51
# Num timesteps: 3660
# Best mean reward: 30.51 - Last mean reward per episode: 30.87
# Saving new best model at 3657 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 3680
# Best mean reward: 30.87 - Last mean reward per episode: 30.87
# Num timesteps: 3700
# Best mean reward: 30.87 - Last mean reward per episode: 31.05
# Saving new best model at 3695 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 3720
# Best mean reward: 31.05 - Last mean reward per episode: 31.05
# Num timesteps: 3740
# Best mean reward: 31.05 - Last mean reward per episode: 31.05
# Num timesteps: 3760
# Best mean reward: 31.05 - Last mean reward per episode: 31.04
# Num timesteps: 3780
# Best mean reward: 31.05 - Last mean reward per episode: 31.13
# Saving new best model at 3765 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 3800
# Best mean reward: 31.13 - Last mean reward per episode: 30.98
# Num timesteps: 3820
# Best mean reward: 31.13 - Last mean reward per episode: 30.98
# Num timesteps: 3840
# Best mean reward: 31.13 - Last mean reward per episode: 31.16
# Saving new best model at 3839 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 3860
# Best mean reward: 31.16 - Last mean reward per episode: 31.16
# Num timesteps: 3880
# Best mean reward: 31.16 - Last mean reward per episode: 31.11
# Num timesteps: 3900
# Best mean reward: 31.16 - Last mean reward per episode: 31.04
# Num timesteps: 3920
# Best mean reward: 31.16 - Last mean reward per episode: 31.04
# Num timesteps: 3940
# Best mean reward: 31.16 - Last mean reward per episode: 31.04
# Num timesteps: 3960
# Best mean reward: 31.16 - Last mean reward per episode: 31.04
# Num timesteps: 3980
# Best mean reward: 31.16 - Last mean reward per episode: 31.38
# Saving new best model at 3977 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 4000
# Best mean reward: 31.38 - Last mean reward per episode: 31.15
# Num timesteps: 4020
# Best mean reward: 31.38 - Last mean reward per episode: 31.15
# Num timesteps: 4040
# Best mean reward: 31.38 - Last mean reward per episode: 31.15
# Num timesteps: 4060
# Best mean reward: 31.38 - Last mean reward per episode: 31.15
# Num timesteps: 4080
# Best mean reward: 31.38 - Last mean reward per episode: 31.15
# Num timesteps: 4100
# Best mean reward: 31.38 - Last mean reward per episode: 31.15
# Num timesteps: 4120
# Best mean reward: 31.38 - Last mean reward per episode: 32.10
# Saving new best model at 4105 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 4140
# Best mean reward: 32.10 - Last mean reward per episode: 32.17
# Saving new best model at 4138 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 4160
# Best mean reward: 32.17 - Last mean reward per episode: 32.17
# Num timesteps: 4180
# Best mean reward: 32.17 - Last mean reward per episode: 32.17
# Num timesteps: 4200
# Best mean reward: 32.17 - Last mean reward per episode: 32.53
# Saving new best model at 4184 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 4220
# Best mean reward: 32.53 - Last mean reward per episode: 32.57
# Saving new best model at 4206 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 4240
# Best mean reward: 32.57 - Last mean reward per episode: 32.57
# Num timesteps: 4260
# Best mean reward: 32.57 - Last mean reward per episode: 32.57
# Num timesteps: 4280
# Best mean reward: 32.57 - Last mean reward per episode: 32.57
# Num timesteps: 4300
# Best mean reward: 32.57 - Last mean reward per episode: 33.02
# Saving new best model at 4282 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 4320
# Best mean reward: 33.02 - Last mean reward per episode: 33.02
# Num timesteps: 4340
# Best mean reward: 33.02 - Last mean reward per episode: 32.93
# Num timesteps: 4360
# Best mean reward: 33.02 - Last mean reward per episode: 32.93
# Num timesteps: 4380
# Best mean reward: 33.02 - Last mean reward per episode: 32.95
# Num timesteps: 4400
# Best mean reward: 33.02 - Last mean reward per episode: 32.95
# Num timesteps: 4420
# Best mean reward: 33.02 - Last mean reward per episode: 32.95
# Num timesteps: 4440
# Best mean reward: 33.02 - Last mean reward per episode: 32.95
# Num timesteps: 4460
# Best mean reward: 33.02 - Last mean reward per episode: 33.60
# Saving new best model at 4452 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 4480
# Best mean reward: 33.60 - Last mean reward per episode: 33.67
# Saving new best model at 4473 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 4500
# Best mean reward: 33.67 - Last mean reward per episode: 33.67
# Num timesteps: 4520
# Best mean reward: 33.67 - Last mean reward per episode: 33.67
# Num timesteps: 4540
# Best mean reward: 33.67 - Last mean reward per episode: 33.67
# Num timesteps: 4560
# Best mean reward: 33.67 - Last mean reward per episode: 34.28
# Saving new best model at 4557 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 4580
# Best mean reward: 34.28 - Last mean reward per episode: 34.28
# Num timesteps: 4600
# Best mean reward: 34.28 - Last mean reward per episode: 34.28
# Num timesteps: 4620
# Best mean reward: 34.28 - Last mean reward per episode: 34.59
# Saving new best model at 4608 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 4640
# Best mean reward: 34.59 - Last mean reward per episode: 34.59
# Num timesteps: 4660
# Best mean reward: 34.59 - Last mean reward per episode: 34.90
# Saving new best model at 4651 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 4680
# Best mean reward: 34.90 - Last mean reward per episode: 34.60
# Num timesteps: 4700
# Best mean reward: 34.90 - Last mean reward per episode: 34.60
# Num timesteps: 4720
# Best mean reward: 34.90 - Last mean reward per episode: 34.60
# Num timesteps: 4740
# Best mean reward: 34.90 - Last mean reward per episode: 34.94
# Saving new best model at 4723 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 4760
# Best mean reward: 34.94 - Last mean reward per episode: 34.94
# Num timesteps: 4780
# Best mean reward: 34.94 - Last mean reward per episode: 34.94
# Num timesteps: 4800
# Best mean reward: 34.94 - Last mean reward per episode: 35.38
# Saving new best model at 4798 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 4820
# Best mean reward: 35.38 - Last mean reward per episode: 35.38
# Num timesteps: 4840
# Best mean reward: 35.38 - Last mean reward per episode: 35.16
# Num timesteps: 4860
# Best mean reward: 35.38 - Last mean reward per episode: 35.25
# Num timesteps: 4880
# Best mean reward: 35.38 - Last mean reward per episode: 35.25
# Num timesteps: 4900
# Best mean reward: 35.38 - Last mean reward per episode: 35.25
# Num timesteps: 4920
# Best mean reward: 35.38 - Last mean reward per episode: 35.69
# Saving new best model at 4907 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 4940
# Best mean reward: 35.69 - Last mean reward per episode: 35.69
# Num timesteps: 4960
# Best mean reward: 35.69 - Last mean reward per episode: 35.69
# Num timesteps: 4980
# Best mean reward: 35.69 - Last mean reward per episode: 36.24
# Saving new best model at 4975 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 5000
# Best mean reward: 36.24 - Last mean reward per episode: 36.24
# Num timesteps: 5020
# Best mean reward: 36.24 - Last mean reward per episode: 36.24
# Num timesteps: 5040
# Best mean reward: 36.24 - Last mean reward per episode: 36.24
# Num timesteps: 5060
# Best mean reward: 36.24 - Last mean reward per episode: 36.24
# Num timesteps: 5080
# Best mean reward: 36.24 - Last mean reward per episode: 36.24
# Num timesteps: 5100
# Best mean reward: 36.24 - Last mean reward per episode: 36.24
# Num timesteps: 5120
# Best mean reward: 36.24 - Last mean reward per episode: 37.34
# Saving new best model at 5101 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 5140
# Best mean reward: 37.34 - Last mean reward per episode: 37.34
# Num timesteps: 5160
# Best mean reward: 37.34 - Last mean reward per episode: 37.34
# Num timesteps: 5180
# Best mean reward: 37.34 - Last mean reward per episode: 37.54
# Saving new best model at 5165 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 5200
# Best mean reward: 37.54 - Last mean reward per episode: 37.54
# Num timesteps: 5220
# Best mean reward: 37.54 - Last mean reward per episode: 37.54
# Num timesteps: 5240
# Best mean reward: 37.54 - Last mean reward per episode: 37.85
# Saving new best model at 5227 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 5260
# Best mean reward: 37.85 - Last mean reward per episode: 38.00
# Saving new best model at 5254 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 5280
# Best mean reward: 38.00 - Last mean reward per episode: 38.00
# Num timesteps: 5300
# Best mean reward: 38.00 - Last mean reward per episode: 38.04
# Saving new best model at 5285 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 5320
# Best mean reward: 38.04 - Last mean reward per episode: 38.04
# Num timesteps: 5340
# Best mean reward: 38.04 - Last mean reward per episode: 38.04
# Num timesteps: 5360
# Best mean reward: 38.04 - Last mean reward per episode: 38.04
# Num timesteps: 5380
# Best mean reward: 38.04 - Last mean reward per episode: 38.58
# Saving new best model at 5370 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 5400
# Best mean reward: 38.58 - Last mean reward per episode: 38.58
# Num timesteps: 5420
# Best mean reward: 38.58 - Last mean reward per episode: 38.58
# Num timesteps: 5440
# Best mean reward: 38.58 - Last mean reward per episode: 38.58
# Num timesteps: 5460
# Best mean reward: 38.58 - Last mean reward per episode: 38.58
# Num timesteps: 5480
# Best mean reward: 38.58 - Last mean reward per episode: 39.33
# Saving new best model at 5475 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 5500
# Best mean reward: 39.33 - Last mean reward per episode: 39.33
# Num timesteps: 5520
# Best mean reward: 39.33 - Last mean reward per episode: 39.33
# Num timesteps: 5540
# Best mean reward: 39.33 - Last mean reward per episode: 39.33
# Num timesteps: 5560
# Best mean reward: 39.33 - Last mean reward per episode: 39.33
# Num timesteps: 5580
# Best mean reward: 39.33 - Last mean reward per episode: 39.33
# Num timesteps: 5600
# Best mean reward: 39.33 - Last mean reward per episode: 39.33
# Num timesteps: 5620
# Best mean reward: 39.33 - Last mean reward per episode: 40.49
# Saving new best model at 5608 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 5640
# Best mean reward: 40.49 - Last mean reward per episode: 40.49
# Num timesteps: 5660
# Best mean reward: 40.49 - Last mean reward per episode: 40.49
# Num timesteps: 5680
# Best mean reward: 40.49 - Last mean reward per episode: 40.49
# Num timesteps: 5700
# Best mean reward: 40.49 - Last mean reward per episode: 40.49
# Num timesteps: 5720
# Best mean reward: 40.49 - Last mean reward per episode: 40.49
# Num timesteps: 5740
# Best mean reward: 40.49 - Last mean reward per episode: 41.42
# Saving new best model at 5723 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 5760
# Best mean reward: 41.42 - Last mean reward per episode: 41.42
# Num timesteps: 5780
# Best mean reward: 41.42 - Last mean reward per episode: 41.42
# Num timesteps: 5800
# Best mean reward: 41.42 - Last mean reward per episode: 41.42
# Num timesteps: 5820
# Best mean reward: 41.42 - Last mean reward per episode: 41.42
# Num timesteps: 5840
# Best mean reward: 41.42 - Last mean reward per episode: 41.42
# Num timesteps: 5860
# Best mean reward: 41.42 - Last mean reward per episode: 41.42
# Num timesteps: 5880
# Best mean reward: 41.42 - Last mean reward per episode: 41.42
# Num timesteps: 5900
# Best mean reward: 41.42 - Last mean reward per episode: 41.42
# Num timesteps: 5920
# Best mean reward: 41.42 - Last mean reward per episode: 41.42
# Num timesteps: 5940
# Best mean reward: 41.42 - Last mean reward per episode: 41.42
# Num timesteps: 5960
# Best mean reward: 41.42 - Last mean reward per episode: 41.42
# Num timesteps: 5980
# Best mean reward: 41.42 - Last mean reward per episode: 41.42
# Num timesteps: 6000
# Best mean reward: 41.42 - Last mean reward per episode: 41.42
# Num timesteps: 6020
# Best mean reward: 41.42 - Last mean reward per episode: 41.42
# Num timesteps: 6040
# Best mean reward: 41.42 - Last mean reward per episode: 41.42
# Num timesteps: 6060
# Best mean reward: 41.42 - Last mean reward per episode: 41.42
# Num timesteps: 6080
# Best mean reward: 41.42 - Last mean reward per episode: 44.06
# Saving new best model at 6069 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 6100
# Best mean reward: 44.06 - Last mean reward per episode: 44.06
# Num timesteps: 6120
# Best mean reward: 44.06 - Last mean reward per episode: 44.06
# Num timesteps: 6140
# Best mean reward: 44.06 - Last mean reward per episode: 44.06
# Num timesteps: 6160
# Best mean reward: 44.06 - Last mean reward per episode: 44.06
# Num timesteps: 6180
# Best mean reward: 44.06 - Last mean reward per episode: 44.06
# Num timesteps: 6200
# Best mean reward: 44.06 - Last mean reward per episode: 45.15
# Saving new best model at 6196 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 6220
# Best mean reward: 45.15 - Last mean reward per episode: 45.15
# Num timesteps: 6240
# Best mean reward: 45.15 - Last mean reward per episode: 45.15
# Num timesteps: 6260
# Best mean reward: 45.15 - Last mean reward per episode: 45.15
# Num timesteps: 6280
# Best mean reward: 45.15 - Last mean reward per episode: 45.15
# Num timesteps: 6300
# Best mean reward: 45.15 - Last mean reward per episode: 45.15
# Num timesteps: 6320
# Best mean reward: 45.15 - Last mean reward per episode: 45.15
# Num timesteps: 6340
# Best mean reward: 45.15 - Last mean reward per episode: 45.15
# Num timesteps: 6360
# Best mean reward: 45.15 - Last mean reward per episode: 45.15
# Num timesteps: 6380
# Best mean reward: 45.15 - Last mean reward per episode: 45.15
# Num timesteps: 6400
# Best mean reward: 45.15 - Last mean reward per episode: 45.15
# Num timesteps: 6420
# Best mean reward: 45.15 - Last mean reward per episode: 45.15
# Num timesteps: 6440
# Best mean reward: 45.15 - Last mean reward per episode: 45.15
# Num timesteps: 6460
# Best mean reward: 45.15 - Last mean reward per episode: 45.15
# Num timesteps: 6480
# Best mean reward: 45.15 - Last mean reward per episode: 47.71
# Saving new best model at 6472 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 6500
# Best mean reward: 47.71 - Last mean reward per episode: 47.71
# Num timesteps: 6520
# Best mean reward: 47.71 - Last mean reward per episode: 47.71
# Num timesteps: 6540
# Best mean reward: 47.71 - Last mean reward per episode: 47.71
# Num timesteps: 6560
# Best mean reward: 47.71 - Last mean reward per episode: 47.71
# Num timesteps: 6580
# Best mean reward: 47.71 - Last mean reward per episode: 47.71
# Num timesteps: 6600
# Best mean reward: 47.71 - Last mean reward per episode: 47.71
# Num timesteps: 6620
# Best mean reward: 47.71 - Last mean reward per episode: 47.71
# Num timesteps: 6640
# Best mean reward: 47.71 - Last mean reward per episode: 47.71
# Num timesteps: 6660
# Best mean reward: 47.71 - Last mean reward per episode: 47.71
# Num timesteps: 6680
# Best mean reward: 47.71 - Last mean reward per episode: 49.52
# Saving new best model at 6669 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 6700
# Best mean reward: 49.52 - Last mean reward per episode: 49.52
# Num timesteps: 6720
# Best mean reward: 49.52 - Last mean reward per episode: 49.52
# Num timesteps: 6740
# Best mean reward: 49.52 - Last mean reward per episode: 49.52
# Num timesteps: 6760
# Best mean reward: 49.52 - Last mean reward per episode: 49.52
# Num timesteps: 6780
# Best mean reward: 49.52 - Last mean reward per episode: 49.52
# Num timesteps: 6800
# Best mean reward: 49.52 - Last mean reward per episode: 49.52
# Num timesteps: 6820
# Best mean reward: 49.52 - Last mean reward per episode: 49.52
# Num timesteps: 6840
# Best mean reward: 49.52 - Last mean reward per episode: 49.52
# Num timesteps: 6860
# Best mean reward: 49.52 - Last mean reward per episode: 49.52
# Num timesteps: 6880
# Best mean reward: 49.52 - Last mean reward per episode: 49.52
# Num timesteps: 6900
# Best mean reward: 49.52 - Last mean reward per episode: 49.52
# Num timesteps: 6920
# Best mean reward: 49.52 - Last mean reward per episode: 49.52
# Num timesteps: 6940
# Best mean reward: 49.52 - Last mean reward per episode: 51.67
# Saving new best model at 6938 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 6960
# Best mean reward: 51.67 - Last mean reward per episode: 51.67
# Num timesteps: 6980
# Best mean reward: 51.67 - Last mean reward per episode: 51.67
# Num timesteps: 7000
# Best mean reward: 51.67 - Last mean reward per episode: 51.67
# Num timesteps: 7020
# Best mean reward: 51.67 - Last mean reward per episode: 51.67
# Num timesteps: 7040
# Best mean reward: 51.67 - Last mean reward per episode: 51.67
# Num timesteps: 7060
# Best mean reward: 51.67 - Last mean reward per episode: 51.67
# Num timesteps: 7080
# Best mean reward: 51.67 - Last mean reward per episode: 51.67
# Num timesteps: 7100
# Best mean reward: 51.67 - Last mean reward per episode: 51.67
# Num timesteps: 7120
# Best mean reward: 51.67 - Last mean reward per episode: 51.67
# Num timesteps: 7140
# Best mean reward: 51.67 - Last mean reward per episode: 51.67
# Num timesteps: 7160
# Best mean reward: 51.67 - Last mean reward per episode: 51.67
# Num timesteps: 7180
# Best mean reward: 51.67 - Last mean reward per episode: 51.67
# Num timesteps: 7200
# Best mean reward: 51.67 - Last mean reward per episode: 51.67
# Num timesteps: 7220
# Best mean reward: 51.67 - Last mean reward per episode: 51.67
# Num timesteps: 7240
# Best mean reward: 51.67 - Last mean reward per episode: 51.67
# Num timesteps: 7260
# Best mean reward: 51.67 - Last mean reward per episode: 51.67
# Num timesteps: 7280
# Best mean reward: 51.67 - Last mean reward per episode: 51.67
# Num timesteps: 7300
# Best mean reward: 51.67 - Last mean reward per episode: 51.67
# Num timesteps: 7320
# Best mean reward: 51.67 - Last mean reward per episode: 55.24
# Saving new best model at 7308 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 7340
# Best mean reward: 55.24 - Last mean reward per episode: 55.24
# Num timesteps: 7360
# Best mean reward: 55.24 - Last mean reward per episode: 55.24
# Num timesteps: 7380
# Best mean reward: 55.24 - Last mean reward per episode: 55.24
# Num timesteps: 7400
# Best mean reward: 55.24 - Last mean reward per episode: 55.24
# Num timesteps: 7420
# Best mean reward: 55.24 - Last mean reward per episode: 55.24
# Num timesteps: 7440
# Best mean reward: 55.24 - Last mean reward per episode: 55.24
# Num timesteps: 7460
# Best mean reward: 55.24 - Last mean reward per episode: 55.24
# Num timesteps: 7480
# Best mean reward: 55.24 - Last mean reward per episode: 55.24
# Num timesteps: 7500
# Best mean reward: 55.24 - Last mean reward per episode: 56.99
# Saving new best model at 7496 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 7520
# Best mean reward: 56.99 - Last mean reward per episode: 56.99
# Num timesteps: 7540
# Best mean reward: 56.99 - Last mean reward per episode: 56.99
# Num timesteps: 7560
# Best mean reward: 56.99 - Last mean reward per episode: 56.99
# Num timesteps: 7580
# Best mean reward: 56.99 - Last mean reward per episode: 56.99
# Num timesteps: 7600
# Best mean reward: 56.99 - Last mean reward per episode: 56.99
# Num timesteps: 7620
# Best mean reward: 56.99 - Last mean reward per episode: 56.99
# Num timesteps: 7640
# Best mean reward: 56.99 - Last mean reward per episode: 56.99
# Num timesteps: 7660
# Best mean reward: 56.99 - Last mean reward per episode: 56.99
# Num timesteps: 7680
# Best mean reward: 56.99 - Last mean reward per episode: 58.63
# Saving new best model at 7672 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 7700
# Best mean reward: 58.63 - Last mean reward per episode: 58.63
# Num timesteps: 7720
# Best mean reward: 58.63 - Last mean reward per episode: 58.63
# Num timesteps: 7740
# Best mean reward: 58.63 - Last mean reward per episode: 58.63
# Num timesteps: 7760
# Best mean reward: 58.63 - Last mean reward per episode: 58.63
# Num timesteps: 7780
# Best mean reward: 58.63 - Last mean reward per episode: 58.63
# Num timesteps: 7800
# Best mean reward: 58.63 - Last mean reward per episode: 59.34
# Saving new best model at 7787 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 7820
# Best mean reward: 59.34 - Last mean reward per episode: 59.34
# Num timesteps: 7840
# Best mean reward: 59.34 - Last mean reward per episode: 59.34
# Num timesteps: 7860
# Best mean reward: 59.34 - Last mean reward per episode: 59.34
# Num timesteps: 7880
# Best mean reward: 59.34 - Last mean reward per episode: 59.34
# Num timesteps: 7900
# Best mean reward: 59.34 - Last mean reward per episode: 59.34
# Num timesteps: 7920
# Best mean reward: 59.34 - Last mean reward per episode: 59.34
# Num timesteps: 7940
# Best mean reward: 59.34 - Last mean reward per episode: 60.59
# Saving new best model at 7938 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 7960
# Best mean reward: 60.59 - Last mean reward per episode: 60.59
# Num timesteps: 7980
# Best mean reward: 60.59 - Last mean reward per episode: 60.59
# Num timesteps: 8000
# Best mean reward: 60.59 - Last mean reward per episode: 60.59
# Num timesteps: 8020
# Best mean reward: 60.59 - Last mean reward per episode: 60.59
# Num timesteps: 8040
# Best mean reward: 60.59 - Last mean reward per episode: 60.59
# Num timesteps: 8060
# Best mean reward: 60.59 - Last mean reward per episode: 60.59
# Num timesteps: 8080
# Best mean reward: 60.59 - Last mean reward per episode: 60.59
# Num timesteps: 8100
# Best mean reward: 60.59 - Last mean reward per episode: 60.59
# Num timesteps: 8120
# Best mean reward: 60.59 - Last mean reward per episode: 62.20
# Saving new best model at 8115 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 8140
# Best mean reward: 62.20 - Last mean reward per episode: 62.20
# Num timesteps: 8160
# Best mean reward: 62.20 - Last mean reward per episode: 62.20
# Num timesteps: 8180
# Best mean reward: 62.20 - Last mean reward per episode: 62.20
# Num timesteps: 8200
# Best mean reward: 62.20 - Last mean reward per episode: 62.20
# Num timesteps: 8220
# Best mean reward: 62.20 - Last mean reward per episode: 62.20
# Num timesteps: 8240
# Best mean reward: 62.20 - Last mean reward per episode: 62.20
# Num timesteps: 8260
# Best mean reward: 62.20 - Last mean reward per episode: 62.20
# Num timesteps: 8280
# Best mean reward: 62.20 - Last mean reward per episode: 63.16
# Saving new best model at 8266 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 8300
# Best mean reward: 63.16 - Last mean reward per episode: 63.16
# Num timesteps: 8320
# Best mean reward: 63.16 - Last mean reward per episode: 63.16
# Num timesteps: 8340
# Best mean reward: 63.16 - Last mean reward per episode: 63.16
# Num timesteps: 8360
# Best mean reward: 63.16 - Last mean reward per episode: 63.16
# Num timesteps: 8380
# Best mean reward: 63.16 - Last mean reward per episode: 63.16
# Num timesteps: 8400
# Best mean reward: 63.16 - Last mean reward per episode: 63.16
# Num timesteps: 8420
# Best mean reward: 63.16 - Last mean reward per episode: 64.34
# Saving new best model at 8406 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 8440
# Best mean reward: 64.34 - Last mean reward per episode: 64.34
# Num timesteps: 8460
# Best mean reward: 64.34 - Last mean reward per episode: 64.34
# Num timesteps: 8480
# Best mean reward: 64.34 - Last mean reward per episode: 64.34
# Num timesteps: 8500
# Best mean reward: 64.34 - Last mean reward per episode: 64.34
# Num timesteps: 8520
# Best mean reward: 64.34 - Last mean reward per episode: 64.34
# Num timesteps: 8540
# Best mean reward: 64.34 - Last mean reward per episode: 65.55
# Saving new best model at 8538 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 8560
# Best mean reward: 65.55 - Last mean reward per episode: 65.55
# Num timesteps: 8580
# Best mean reward: 65.55 - Last mean reward per episode: 65.55
# Num timesteps: 8600
# Best mean reward: 65.55 - Last mean reward per episode: 65.55
# Num timesteps: 8620
# Best mean reward: 65.55 - Last mean reward per episode: 65.55
# Num timesteps: 8640
# Best mean reward: 65.55 - Last mean reward per episode: 65.55
# Num timesteps: 8660
# Best mean reward: 65.55 - Last mean reward per episode: 65.55
# Num timesteps: 8680
# Best mean reward: 65.55 - Last mean reward per episode: 65.55
# Num timesteps: 8700
# Best mean reward: 65.55 - Last mean reward per episode: 66.34
# Saving new best model at 8686 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 8720
# Best mean reward: 66.34 - Last mean reward per episode: 66.34
# Num timesteps: 8740
# Best mean reward: 66.34 - Last mean reward per episode: 66.34
# Num timesteps: 8760
# Best mean reward: 66.34 - Last mean reward per episode: 66.34
# Num timesteps: 8780
# Best mean reward: 66.34 - Last mean reward per episode: 66.34
# Num timesteps: 8800
# Best mean reward: 66.34 - Last mean reward per episode: 66.34
# Num timesteps: 8820
# Best mean reward: 66.34 - Last mean reward per episode: 66.34
# Num timesteps: 8840
# Best mean reward: 66.34 - Last mean reward per episode: 66.34
# Num timesteps: 8860
# Best mean reward: 66.34 - Last mean reward per episode: 66.34
# Num timesteps: 8880
# Best mean reward: 66.34 - Last mean reward per episode: 66.34
# Num timesteps: 8900
# Best mean reward: 66.34 - Last mean reward per episode: 67.89
# Saving new best model at 8884 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 8920
# Best mean reward: 67.89 - Last mean reward per episode: 67.89
# Num timesteps: 8940
# Best mean reward: 67.89 - Last mean reward per episode: 67.89
# Num timesteps: 8960
# Best mean reward: 67.89 - Last mean reward per episode: 67.89
# Num timesteps: 8980
# Best mean reward: 67.89 - Last mean reward per episode: 67.89
# Num timesteps: 9000
# Best mean reward: 67.89 - Last mean reward per episode: 67.89
# Num timesteps: 9020
# Best mean reward: 67.89 - Last mean reward per episode: 67.89
# Num timesteps: 9040
# Best mean reward: 67.89 - Last mean reward per episode: 67.89
# Num timesteps: 9060
# Best mean reward: 67.89 - Last mean reward per episode: 67.89
# Num timesteps: 9080
# Best mean reward: 67.89 - Last mean reward per episode: 67.89
# Num timesteps: 9100
# Best mean reward: 67.89 - Last mean reward per episode: 69.38
# Saving new best model at 9083 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 9120
# Best mean reward: 69.38 - Last mean reward per episode: 69.38
# Num timesteps: 9140
# Best mean reward: 69.38 - Last mean reward per episode: 69.38
# Num timesteps: 9160
# Best mean reward: 69.38 - Last mean reward per episode: 69.38
# Num timesteps: 9180
# Best mean reward: 69.38 - Last mean reward per episode: 69.38
# Num timesteps: 9200
# Best mean reward: 69.38 - Last mean reward per episode: 69.38
# Num timesteps: 9220
# Best mean reward: 69.38 - Last mean reward per episode: 70.36
# Saving new best model at 9203 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 9240
# Best mean reward: 70.36 - Last mean reward per episode: 70.36
# Num timesteps: 9260
# Best mean reward: 70.36 - Last mean reward per episode: 70.36
# Num timesteps: 9280
# Best mean reward: 70.36 - Last mean reward per episode: 70.36
# Num timesteps: 9300
# Best mean reward: 70.36 - Last mean reward per episode: 70.36
# Num timesteps: 9320
# Best mean reward: 70.36 - Last mean reward per episode: 70.36
# Num timesteps: 9340
# Best mean reward: 70.36 - Last mean reward per episode: 70.36
# Num timesteps: 9360
# Best mean reward: 70.36 - Last mean reward per episode: 70.36
# Num timesteps: 9380
# Best mean reward: 70.36 - Last mean reward per episode: 71.54
# Saving new best model at 9368 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 9400
# Best mean reward: 71.54 - Last mean reward per episode: 71.54
# Num timesteps: 9420
# Best mean reward: 71.54 - Last mean reward per episode: 71.54
# Num timesteps: 9440
# Best mean reward: 71.54 - Last mean reward per episode: 71.54
# Num timesteps: 9460
# Best mean reward: 71.54 - Last mean reward per episode: 71.93
# Saving new best model at 9455 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 9480
# Best mean reward: 71.93 - Last mean reward per episode: 71.93
# Num timesteps: 9500
# Best mean reward: 71.93 - Last mean reward per episode: 71.93
# Num timesteps: 9520
# Best mean reward: 71.93 - Last mean reward per episode: 71.93
# Num timesteps: 9540
# Best mean reward: 71.93 - Last mean reward per episode: 71.93
# Num timesteps: 9560
# Best mean reward: 71.93 - Last mean reward per episode: 71.93
# Num timesteps: 9580
# Best mean reward: 71.93 - Last mean reward per episode: 71.93
# Num timesteps: 9600
# Best mean reward: 71.93 - Last mean reward per episode: 71.93
# Num timesteps: 9620
# Best mean reward: 71.93 - Last mean reward per episode: 71.93
# Num timesteps: 9640
# Best mean reward: 71.93 - Last mean reward per episode: 71.93
# Num timesteps: 9660
# Best mean reward: 71.93 - Last mean reward per episode: 71.93
# Num timesteps: 9680
# Best mean reward: 71.93 - Last mean reward per episode: 71.93
# Num timesteps: 9700
# Best mean reward: 71.93 - Last mean reward per episode: 71.93
# Num timesteps: 9720
# Best mean reward: 71.93 - Last mean reward per episode: 71.93
# Num timesteps: 9740
# Best mean reward: 71.93 - Last mean reward per episode: 74.65
# Saving new best model at 9740 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 9760
# Best mean reward: 74.65 - Last mean reward per episode: 74.65
# Num timesteps: 9780
# Best mean reward: 74.65 - Last mean reward per episode: 74.65
# Num timesteps: 9800
# Best mean reward: 74.65 - Last mean reward per episode: 74.65
# Num timesteps: 9820
# Best mean reward: 74.65 - Last mean reward per episode: 74.65
# Num timesteps: 9840
# Best mean reward: 74.65 - Last mean reward per episode: 74.65
# Num timesteps: 9860
# Best mean reward: 74.65 - Last mean reward per episode: 74.65
# Num timesteps: 9880
# Best mean reward: 74.65 - Last mean reward per episode: 74.65
# Num timesteps: 9900
# Best mean reward: 74.65 - Last mean reward per episode: 75.85
# Saving new best model at 9885 timesteps
# Saving new best model to /home/gkoren2/share/data/study/sbl3/tmp/gym/best_model.zip
# Num timesteps: 9920
# Best mean reward: 75.85 - Last mean reward per episode: 75.85
# Num timesteps: 9940
# Best mean reward: 75.85 - Last mean reward per episode: 75.85
# Num timesteps: 9960
# Best mean reward: 75.85 - Last mean reward per episode: 75.85
# Num timesteps: 9980
# Best mean reward: 75.85 - Last mean reward per episode: 75.85
# Num timesteps: 10000
# Best mean reward: 75.85 - Last mean reward per episode: 75.85

# %% [markdown]
# ## Second example: Realtime plotting of performance
# While training, it is sometimes useful to how the training progresses over time, relative to the episodic reward.
# For this, Stable-Baselines has [Tensorboard support](https://stable-baselines.readthedocs.io/en/master/guide/tensorboard.html), however this can be very combersome, especially in disk space usage.
#
# **NOTE: Unfortunately live plotting does not work out of the box on google colab**
#
# Here, we can use callback again, to plot the episodic reward in realtime, using the monitoring wrapper:

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib notebook


class PlottingCallback(BaseCallback):
    """
    Callback for plotting the performance in realtime.

    :param verbose: (int)
    """
    def __init__(self, verbose=1):
        super(PlottingCallback, self).__init__(verbose)
        self._plot = None

    def _on_step(self) -> bool:
        # get the monitor's data
        x, y = ts2xy(load_results(log_dir), 'timesteps')
        if self._plot is None: # make the plot
            plt.ion()
            fig = plt.figure(figsize=(6,3))
            ax = fig.add_subplot(111)
            line, = ax.plot(x, y)
            self._plot = (line, ax, fig)
            plt.show()
        else: # update and rescale the plot
            self._plot[0].set_data(x, y)
            self._plot[-2].relim()
            self._plot[-2].set_xlim([self.locals["total_timesteps"] * -0.02, 
                                     self.locals["total_timesteps"] * 1.02])
            self._plot[-2].autoscale_view(True,True,True)
            self._plot[-1].canvas.draw()
        
# Create log dir
# log_dir = "/tmp/gym/"
log_dir = os.path.join(os.path.expanduser('~'),'share','data','study','sbl3','tmp/gym/')
os.makedirs(log_dir, exist_ok=True)

# Create and wrap the environment
env = make_vec_env('MountainCarContinuous-v0', n_envs=1, monitor_dir=log_dir)

plotting_callback = PlottingCallback()
        
model = PPO('MlpPolicy', env, verbose=0)
model.learn(20000, callback=plotting_callback)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %% [markdown]
# ## Third example: Progress bar
# Quality of life improvement are always welcome when developping and using RL. Here, we used [tqdm](https://tqdm.github.io/) to show a progress bar of the training, along with number of timesteps per second and the estimated time remaining to the end of the training:

# %%
from tqdm.auto import tqdm

class ProgressBarCallback(BaseCallback):
    """
    :param pbar: (tqdm.pbar) Progress bar object
    """
    def __init__(self, pbar):
        super(ProgressBarCallback, self).__init__()
        self._pbar = pbar

    def _on_step(self):
        # Update the progress bar:
        self._pbar.n = self.num_timesteps
        self._pbar.update(0)

# this callback uses the 'with' block, allowing for correct initialisation and destruction
class ProgressBarManager(object):
    def __init__(self, total_timesteps): # init object with total timesteps
        self.pbar = None
        self.total_timesteps = total_timesteps
        
    def __enter__(self): # create the progress bar and callback, return the callback
        self.pbar = tqdm(total=self.total_timesteps)
            
        return ProgressBarCallback(self.pbar)

    def __exit__(self, exc_type, exc_val, exc_tb): # close the callback
        self.pbar.n = self.total_timesteps
        self.pbar.update(0)
        self.pbar.close()
        
model = TD3('MlpPolicy', 'Pendulum-v0', verbose=0)
with ProgressBarManager(2000) as callback: # this the garanties that the tqdm progress bar closes correctly
    model.learn(2000, callback=callback)

# %% [markdown]
# ## Forth example: Composition
# Thanks to the functional nature of callbacks, it is possible to do a composition of callbacks, into a single callback. This means we can auto save our best model, show the progess bar and episodic reward of the training.
#
# The callbacks are automatically composed when you pass a list to the `learn()` method. Under the hood, a `CallbackList` is created.

# %%
from stable_baselines3.common.callbacks import CallbackList

# Create log dir
log_dir = os.path.join(os.path.expanduser('~'),'share','Data','study','sbl3','tmp/gym/')
os.makedirs(log_dir, exist_ok=True)

# Create and wrap the environment
env = make_vec_env('CartPole-v1', n_envs=1, monitor_dir=log_dir)

# Create callbacks
auto_save_callback = SaveOnBestTrainingRewardCallback(check_freq=1000, log_dir=log_dir)

model = PPO('MlpPolicy', env, verbose=0)
with ProgressBarManager(10000) as progress_callback:
    # This is equivalent to callback=CallbackList([progress_callback, auto_save_callback])
    model.learn(10000, callback=[progress_callback, auto_save_callback])

# %% [markdown]
# ## Exercise: Code your own callback
#
#
# The previous examples showed the basics of what is a callback and what you do with it.
#
# The goal of this exercise is to create a callback that will evaluate the model using a test environment and save it if this is the best known model.
#
# To make things easier, we are going to use a class instead of a function with the magic method `__call__`.

# %%
from stable_baselines3.common.evaluation import evaluate_policy
class EvalCallback(BaseCallback):
    """
    Callback for evaluating an agent.

    :param eval_env: (gym.Env) The environment used for initialization
    :param n_eval_episodes: (int) The number of episodes to test the agent
    :param eval_freq: (int) Evaluate the agent every eval_freq call of the callback.
    """
    def __init__(self, eval_env, save_path, n_eval_episodes=5, eval_freq=20):
        super(EvalCallback, self).__init__()
        self.eval_env = eval_env
        self.n_eval_episodes = n_eval_episodes
        self.eval_freq = eval_freq
        self.best_mean_reward = -np.inf
        os.makedirs(save_path, exist_ok=True)
        self.save_path = os.path.join(save_path, 'best_model')
        
    def _on_step(self):
        """
        This method will be called by the model.

        :return: (bool)
        """
    
        # self.n_calls is automatically updated because
        # we derive from BaseCallback
        if self.n_calls % self.eval_freq == 0:
            # === YOUR CODE HERE ===#
            # Evaluate the agent:
            # you need to do self.n_eval_episodes loop using self.eval_env
            # hint: you can use self.model.predict(obs, deterministic=True)
            mean_reward, std_reward = evaluate_policy(self.model, self.eval_env, n_eval_episodes=self.n_eval_episodes)
            # Save the agent if needed
            if mean_reward > self.best_mean_reward:
                
                self.model.save(self.save_path)
                # and update self.best_mean_reward
                self.best_mean_reward = mean_reward
                print("Best mean reward: {:.2f}".format(self.best_mean_reward))
                print(f'saving model to {self.save_path}')
            # ====================== #    
        return True

# %% [markdown]
# ### Test your callback

# %%
# Env used for training
env = gym.make("CartPole-v1")
# Env for evaluating the agent
eval_env = gym.make("CartPole-v1")

# === YOUR CODE HERE ===#
# Create the callback object
callback = EvalCallback(eval_env=eval_env,save_path=log_dir)

# Create the RL model
model = PPO('MlpPolicy', env, verbose=0)

# ====================== #

# Train the RL model
model.learn(int(100000), callback=callback)
# Out:
# Best mean reward: 47.20
# saving model to /home/gkoren2/share/Data/study/sbl3/tmp/gym/best_model
# Best mean reward: 57.20
# saving model to /home/gkoren2/share/Data/study/sbl3/tmp/gym/best_model
# Best mean reward: 71.00
# saving model to /home/gkoren2/share/Data/study/sbl3/tmp/gym/best_model
# Best mean reward: 77.20
# saving model to /home/gkoren2/share/Data/study/sbl3/tmp/gym/best_model
# Best mean reward: 78.40
# saving model to /home/gkoren2/share/Data/study/sbl3/tmp/gym/best_model
# Best mean reward: 81.80
# saving model to /home/gkoren2/share/Data/study/sbl3/tmp/gym/best_model
# Best mean reward: 116.00
# saving model to /home/gkoren2/share/Data/study/sbl3/tmp/gym/best_model
# Best mean reward: 116.20
# saving model to /home/gkoren2/share/Data/study/sbl3/tmp/gym/best_model
# Best mean reward: 130.60
# saving model to /home/gkoren2/share/Data/study/sbl3/tmp/gym/best_model
# Best mean reward: 155.40
# saving model to /home/gkoren2/share/Data/study/sbl3/tmp/gym/best_model
# Best mean reward: 157.60
# saving model to /home/gkoren2/share/Data/study/sbl3/tmp/gym/best_model
# Best mean reward: 394.60
# saving model to /home/gkoren2/share/Data/study/sbl3/tmp/gym/best_model
# Best mean reward: 490.40
# saving model to /home/gkoren2/share/Data/study/sbl3/tmp/gym/best_model
# Best mean reward: 494.00
# saving model to /home/gkoren2/share/Data/study/sbl3/tmp/gym/best_model
# Best mean reward: 500.00
# saving model to /home/gkoren2/share/Data/study/sbl3/tmp/gym/best_model
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-9a3c505369f6> in <module>
#      14
#      15 # Train the RL model
# ---> 16 model.learn(int(100000), callback=callback)
#
# ~/PycharmProjects/remote/study/stable-baselines3/stable_baselines3/ppo/ppo.py in learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     261             tb_log_name=tb_log_name,
#     262             eval_log_path=eval_log_path,
# --> 263             reset_num_timesteps=reset_num_timesteps,
#     264         )
#
# ~/PycharmProjects/remote/study/stable-baselines3/stable_baselines3/common/on_policy_algorithm.py in learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     222         while self.num_timesteps < total_timesteps:
#     223
# --> 224             continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     225
#     226             if continue_training is False:
#
# ~/PycharmProjects/remote/study/stable-baselines3/stable_baselines3/common/on_policy_algorithm.py in collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps)
#     169             # Give access to local variables
#     170             callback.update_locals(locals())
# --> 171             if callback.on_step() is False:
#     172                 return False
#     173
#
# ~/PycharmProjects/remote/study/stable-baselines3/stable_baselines3/common/callbacks.py in on_step(self)
#      86         self.num_timesteps = self.model.num_timesteps
#      87
# ---> 88         return self._on_step()
#      89
#      90     def on_training_end(self) -> None:
#
# <ipython-input-26-241223049698> in _on_step(self)
#      31             # you need to do self.n_eval_episodes loop using self.eval_env
#      32             # hint: you can use self.model.predict(obs, deterministic=True)
# ---> 33             mean_reward, std_reward = evaluate_policy(self.model, self.eval_env, n_eval_episodes=self.n_eval_episodes)
#      34             # Save the agent if needed
#      35             if mean_reward > self.best_mean_reward:
#
# ~/PycharmProjects/remote/study/stable-baselines3/stable_baselines3/common/evaluation.py in evaluate_policy(model, env, n_eval_episodes, deterministic, render, callback, reward_threshold, return_episode_rewards)
#      49         episode_length = 0
#      50         while not done:
# ---> 51             action, state = model.predict(obs, state=state, deterministic=deterministic)
#      52             obs, reward, done, _info = env.step(action)
#      53             episode_reward += reward
#
# ~/PycharmProjects/remote/study/stable-baselines3/stable_baselines3/common/base_class.py in predict(self, observation, state, mask, deterministic)
#     475             (used in recurrent policies)
#     476         """
# --> 477         return self.policy.predict(observation, state, mask, deterministic)
#     478
#     479     def set_random_seed(self, seed: Optional[int] = None) -> None:
#
# ~/PycharmProjects/remote/study/stable-baselines3/stable_baselines3/common/policies.py in predict(self, observation, state, mask, deterministic)
#     285         observation = th.as_tensor(observation).to(self.device)
#     286         with th.no_grad():
# --> 287             actions = self._predict(observation, deterministic=deterministic)
#     288         # Convert to numpy
#     289         actions = actions.cpu().numpy()
#
# ~/PycharmProjects/remote/study/stable-baselines3/stable_baselines3/common/policies.py in _predict(self, observation, deterministic)
#     604         :return: Taken action according to the policy
#     605         """
# --> 606         latent_pi, _, latent_sde = self._get_latent(observation)
#     607         distribution = self._get_action_dist_from_latent(latent_pi, latent_sde)
#     608         return distribution.get_actions(deterministic=deterministic)
#
# ~/PycharmProjects/remote/study/stable-baselines3/stable_baselines3/common/policies.py in _get_latent(self, obs)
#     562         # Preprocess the observation if needed
#     563         features = self.extract_features(obs)
# --> 564         latent_pi, latent_vf = self.mlp_extractor(features)
#     565
#     566         # Features for sde
#
# /opt/anaconda3/envs/sbl/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~/PycharmProjects/remote/study/stable-baselines3/stable_baselines3/common/torch_layers.py in forward(self, features)
#     222         """
#     223         shared_latent = self.shared_net(features)
# --> 224         return self.policy_net(shared_latent), self.value_net(shared_latent)
#     225
#     226
#
# /opt/anaconda3/envs/sbl/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# /opt/anaconda3/envs/sbl/lib/python3.7/site-packages/torch/nn/modules/container.py in forward(self, input)
#     115     def forward(self, input):
#     116         for module in self:
# --> 117             input = module(input)
#     118         return input
#     119
#
# /opt/anaconda3/envs/sbl/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# /opt/anaconda3/envs/sbl/lib/python3.7/site-packages/torch/nn/modules/linear.py in forward(self, input)
#      91
#      92     def forward(self, input: Tensor) -> Tensor:
# ---> 93         return F.linear(input, self.weight, self.bias)
#      94
#      95     def extra_repr(self) -> str:
#
# /opt/anaconda3/envs/sbl/lib/python3.7/site-packages/torch/nn/functional.py in linear(input, weight, bias)
#    1688     if input.dim() == 2 and bias is not None:
#    1689         # fused op is marginally faster
# -> 1690         ret = torch.addmm(bias, input, weight.t())
#    1691     else:
#    1692         output = input.matmul(weight.t())
#
# KeyboardInterrupt:

# %% [markdown]
# # Conclusion
#
#
# In this notebook we have seen:
# - that good hyperparameters are key to the success of RL, you should not except the default ones to work on every problems
# - what is a callback and what you can do with it
# - how to create your own callback
