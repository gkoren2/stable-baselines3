# %% [markdown]
# <a href="https://colab.research.google.com/github/Stable-Baselines-Team/rl-colab-notebooks/blob/sb3/saving_loading_dqn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Stable Baselines3 - Training, Saving and Loading
#
# Github Repo: [https://github.com/DLR-RM/stable-baselines3](https://github.com/DLR-RM/stable-baselines3)
#
#
# [RL Baselines3 Zoo](https://github.com/DLR-RM/rl-baselines3-zoo) is a collection of pre-trained Reinforcement Learning agents using Stable-Baselines3.
#
# It also provides basic scripts for training, evaluating agents, tuning hyperparameters and recording videos.
#
# Documentation is available online: [https://stable-baselines3.readthedocs.io/](https://stable-baselines3.readthedocs.io/)
#
# ## Install Dependencies and Stable Baselines Using Pip
#
#
# ```
# pip install stable-baselines3[extra]
# ```

# %%
# !apt install swig cmake
# !pip install stable-baselines3[extra] box2d box2d-kengz

# %%
import os
import sys
path_to_curr_file=os.path.realpath(os.getcwd())
proj_root=os.path.dirname(os.path.dirname(path_to_curr_file))
if proj_root not in sys.path:
    sys.path.insert(0,proj_root)

# %% [markdown]
# ## Import policy, RL agent, ...

# %%
import gym
import numpy as np

from stable_baselines3 import DQN

# %% [markdown]
# ## Create the Gym env and instantiate the agent
#
# For this example, we will use Lunar Lander environment.
#
# "Landing outside landing pad is possible. Fuel is infinite, so an agent can learn to fly and then land on its first attempt. Four discrete actions available: do nothing, fire left orientation engine, fire main engine, fire right orientation engine. "
#
# Lunar Lander environment: [https://gym.openai.com/envs/LunarLander-v2/](https://gym.openai.com/envs/LunarLander-v2/)
#
# ![Lunar Lander](https://cdn-images-1.medium.com/max/960/1*f4VZPKOI0PYNWiwt0la0Rg.gif)
#
#
# We chose the MlpPolicy because input of Lunar Lander is a feature vector, not images.
#
# The type of action to use (discrete/continuous) will be automatically deduced from the environment action space

# %%
model = DQN('MlpPolicy', 'LunarLander-v2', verbose=1, exploration_final_eps=0.1, target_update_interval=250)
# Out:
# Using cuda device
# Creating environment from the given name 'LunarLander-v2'
# Wrapping the env in a DummyVecEnv.

# %% [markdown]
# We load a helper function to evaluate the agent:

# %%
from stable_baselines3.common.evaluation import evaluate_policy

# %% [markdown]
# Let's evaluate the un-trained agent, this should be a random agent.

# %%
# Separate env for evaluation
eval_env = gym.make('LunarLander-v2')

# Random Agent, before training
mean_reward, std_reward = evaluate_policy(model, eval_env, n_eval_episodes=10, deterministic=True)

print(f"mean_reward={mean_reward:.2f} +/- {std_reward}")
# Out:
# mean_reward=-669.76 +/- 203.27022412774187

# %% [markdown]
# ## Train the agent and save it
#
# Warning: this may take a while

# %%
# Train the agent
model.learn(total_timesteps=int(1e5))
# Save the agent
model.save("dqn_lunar")
del model  # delete trained model to demonstrate loading
# Out:
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.2     |
# |    ep_rew_mean      | -196     |
# |    exploration rate | 0.964    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 3218     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 397      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.1     |
# |    ep_rew_mean      | -159     |
# |    exploration rate | 0.933    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 3499     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 745      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93       |
# |    ep_rew_mean      | -157     |
# |    exploration rate | 0.9      |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 3572     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1116     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.1     |
# |    ep_rew_mean      | -162     |
# |    exploration rate | 0.862    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 3607     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1537     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.8     |
# |    ep_rew_mean      | -162     |
# |    exploration rate | 0.829    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 3651     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1896     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.3     |
# |    ep_rew_mean      | -173     |
# |    exploration rate | 0.794    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 3679     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2287     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.3     |
# |    ep_rew_mean      | -174     |
# |    exploration rate | 0.755    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 3664     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2725     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.1     |
# |    ep_rew_mean      | -181     |
# |    exploration rate | 0.723    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 3676     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3075     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.1     |
# |    ep_rew_mean      | -194     |
# |    exploration rate | 0.679    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 3666     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3569     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98       |
# |    ep_rew_mean      | -196     |
# |    exploration rate | 0.647    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 3686     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 3921     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.4     |
# |    ep_rew_mean      | -191     |
# |    exploration rate | 0.622    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 3690     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 4199     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.3     |
# |    ep_rew_mean      | -186     |
# |    exploration rate | 0.593    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 3688     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 4526     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.9     |
# |    ep_rew_mean      | -191     |
# |    exploration rate | 0.556    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 3699     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 4934     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.3     |
# |    ep_rew_mean      | -191     |
# |    exploration rate | 0.525    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 3707     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 5279     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.8     |
# |    ep_rew_mean      | -190     |
# |    exploration rate | 0.493    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 3715     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 5630     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.2     |
# |    ep_rew_mean      | -189     |
# |    exploration rate | 0.463    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 3721     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 5963     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.2     |
# |    ep_rew_mean      | -190     |
# |    exploration rate | 0.423    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 3710     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 6409     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.4     |
# |    ep_rew_mean      | -185     |
# |    exploration rate | 0.395    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 3712     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 6725     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.6     |
# |    ep_rew_mean      | -180     |
# |    exploration rate | 0.366    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 3723     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 7041     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92       |
# |    ep_rew_mean      | -176     |
# |    exploration rate | 0.337    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 3732     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 7363     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.9     |
# |    ep_rew_mean      | -177     |
# |    exploration rate | 0.305    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 3736     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 7717     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.8     |
# |    ep_rew_mean      | -177     |
# |    exploration rate | 0.273    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 3732     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 8075     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.4     |
# |    ep_rew_mean      | -179     |
# |    exploration rate | 0.243    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 3732     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 8407     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.2     |
# |    ep_rew_mean      | -178     |
# |    exploration rate | 0.212    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 3733     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 8752     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.1     |
# |    ep_rew_mean      | -176     |
# |    exploration rate | 0.18     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 3735     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 9108     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.4     |
# |    ep_rew_mean      | -177     |
# |    exploration rate | 0.142    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 3728     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 9534     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.3     |
# |    ep_rew_mean      | -178     |
# |    exploration rate | 0.112    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 3733     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 9872     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.8     |
# |    ep_rew_mean      | -179     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 3741     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 10192    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.3     |
# |    ep_rew_mean      | -178     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 3740     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 10564    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | -176     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 3743     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 10899    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.1     |
# |    ep_rew_mean      | -175     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 3741     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 11299    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.2     |
# |    ep_rew_mean      | -179     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 3737     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 11741    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.3     |
# |    ep_rew_mean      | -176     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 3735     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 12106    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.8     |
# |    ep_rew_mean      | -167     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 3737     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 12450    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.2     |
# |    ep_rew_mean      | -161     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 3739     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 12739    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.9     |
# |    ep_rew_mean      | -166     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 3737     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 13190    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.1     |
# |    ep_rew_mean      | -169     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 3738     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 13536    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.2     |
# |    ep_rew_mean      | -165     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 3740     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 13850    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.5     |
# |    ep_rew_mean      | -166     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 3743     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 14226    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.8     |
# |    ep_rew_mean      | -165     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 3748     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 14606    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.2     |
# |    ep_rew_mean      | -165     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 3750     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 14981    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.6     |
# |    ep_rew_mean      | -162     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 3753     |
# |    time_elapsed     | 4        |
# |    total timesteps  | 15269    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.7     |
# |    ep_rew_mean      | -168     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 3755     |
# |    time_elapsed     | 4        |
# |    total timesteps  | 15594    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.8     |
# |    ep_rew_mean      | -169     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 3754     |
# |    time_elapsed     | 4        |
# |    total timesteps  | 15925    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.5     |
# |    ep_rew_mean      | -175     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 3753     |
# |    time_elapsed     | 4        |
# |    total timesteps  | 16312    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.1     |
# |    ep_rew_mean      | -173     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 3751     |
# |    time_elapsed     | 4        |
# |    total timesteps  | 16723    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | -174     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 3752     |
# |    time_elapsed     | 4        |
# |    total timesteps  | 17078    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.5     |
# |    ep_rew_mean      | -172     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 3752     |
# |    time_elapsed     | 4        |
# |    total timesteps  | 17452    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.9     |
# |    ep_rew_mean      | -173     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 3751     |
# |    time_elapsed     | 4        |
# |    total timesteps  | 17842    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.7     |
# |    ep_rew_mean      | -173     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 3752     |
# |    time_elapsed     | 4        |
# |    total timesteps  | 18182    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.1     |
# |    ep_rew_mean      | -172     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 3751     |
# |    time_elapsed     | 4        |
# |    total timesteps  | 18547    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.2     |
# |    ep_rew_mean      | -175     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 3752     |
# |    time_elapsed     | 5        |
# |    total timesteps  | 18897    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.8     |
# |    ep_rew_mean      | -172     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 3753     |
# |    time_elapsed     | 5        |
# |    total timesteps  | 19271    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.5     |
# |    ep_rew_mean      | -170     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 3756     |
# |    time_elapsed     | 5        |
# |    total timesteps  | 19619    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.6     |
# |    ep_rew_mean      | -177     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 3756     |
# |    time_elapsed     | 5        |
# |    total timesteps  | 19962    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.7     |
# |    ep_rew_mean      | -175     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 3754     |
# |    time_elapsed     | 5        |
# |    total timesteps  | 20371    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.1     |
# |    ep_rew_mean      | -171     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 3755     |
# |    time_elapsed     | 5        |
# |    total timesteps  | 20747    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.5     |
# |    ep_rew_mean      | -172     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 3756     |
# |    time_elapsed     | 5        |
# |    total timesteps  | 21161    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.4     |
# |    ep_rew_mean      | -177     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 3758     |
# |    time_elapsed     | 5        |
# |    total timesteps  | 21490    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.3     |
# |    ep_rew_mean      | -179     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 3758     |
# |    time_elapsed     | 5        |
# |    total timesteps  | 21873    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91       |
# |    ep_rew_mean      | -178     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 3756     |
# |    time_elapsed     | 5        |
# |    total timesteps  | 22290    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91       |
# |    ep_rew_mean      | -177     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 3756     |
# |    time_elapsed     | 6        |
# |    total timesteps  | 22639    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91       |
# |    ep_rew_mean      | -179     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 3758     |
# |    time_elapsed     | 6        |
# |    total timesteps  | 22954    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.3     |
# |    ep_rew_mean      | -179     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 3759     |
# |    time_elapsed     | 6        |
# |    total timesteps  | 23355    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.2     |
# |    ep_rew_mean      | -180     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 3758     |
# |    time_elapsed     | 6        |
# |    total timesteps  | 23730    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.2     |
# |    ep_rew_mean      | -180     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 3757     |
# |    time_elapsed     | 6        |
# |    total timesteps  | 24104    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.1     |
# |    ep_rew_mean      | -183     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 3758     |
# |    time_elapsed     | 6        |
# |    total timesteps  | 24483    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.6     |
# |    ep_rew_mean      | -179     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 3757     |
# |    time_elapsed     | 6        |
# |    total timesteps  | 24851    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.3     |
# |    ep_rew_mean      | -184     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 3759     |
# |    time_elapsed     | 6        |
# |    total timesteps  | 25158    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.1     |
# |    ep_rew_mean      | -184     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 3758     |
# |    time_elapsed     | 6        |
# |    total timesteps  | 25526    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.7     |
# |    ep_rew_mean      | -186     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 3759     |
# |    time_elapsed     | 6        |
# |    total timesteps  | 25890    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.7     |
# |    ep_rew_mean      | -185     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 3759     |
# |    time_elapsed     | 7        |
# |    total timesteps  | 26348    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | -182     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 3387     |
# |    time_elapsed     | 8        |
# |    total timesteps  | 27577    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | -181     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 3392     |
# |    time_elapsed     | 8        |
# |    total timesteps  | 27911    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | -183     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 3396     |
# |    time_elapsed     | 8        |
# |    total timesteps  | 28270    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | -184     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 3400     |
# |    time_elapsed     | 8        |
# |    total timesteps  | 28618    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | -179     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 3405     |
# |    time_elapsed     | 8        |
# |    total timesteps  | 28975    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | -177     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 3408     |
# |    time_elapsed     | 8        |
# |    total timesteps  | 29299    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.9     |
# |    ep_rew_mean      | -180     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 3413     |
# |    time_elapsed     | 8        |
# |    total timesteps  | 29610    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | -179     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 3417     |
# |    time_elapsed     | 8        |
# |    total timesteps  | 29995    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.6     |
# |    ep_rew_mean      | -175     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 3421     |
# |    time_elapsed     | 8        |
# |    total timesteps  | 30332    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.1     |
# |    ep_rew_mean      | -172     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 3425     |
# |    time_elapsed     | 8        |
# |    total timesteps  | 30653    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98       |
# |    ep_rew_mean      | -168     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 3430     |
# |    time_elapsed     | 9        |
# |    total timesteps  | 30963    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.5     |
# |    ep_rew_mean      | -167     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 3433     |
# |    time_elapsed     | 9        |
# |    total timesteps  | 31336    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.8     |
# |    ep_rew_mean      | -172     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 3435     |
# |    time_elapsed     | 9        |
# |    total timesteps  | 31752    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.7     |
# |    ep_rew_mean      | -171     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 3439     |
# |    time_elapsed     | 9        |
# |    total timesteps  | 32161    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99       |
# |    ep_rew_mean      | -171     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 3441     |
# |    time_elapsed     | 9        |
# |    total timesteps  | 32540    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.8     |
# |    ep_rew_mean      | -172     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 3444     |
# |    time_elapsed     | 9        |
# |    total timesteps  | 32935    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.3     |
# |    ep_rew_mean      | -170     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 3447     |
# |    time_elapsed     | 9        |
# |    total timesteps  | 33286    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.7     |
# |    ep_rew_mean      | -167     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 3450     |
# |    time_elapsed     | 9        |
# |    total timesteps  | 33695    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | -167     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 3453     |
# |    time_elapsed     | 9        |
# |    total timesteps  | 34115    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | -164     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 3456     |
# |    time_elapsed     | 9        |
# |    total timesteps  | 34485    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.5     |
# |    ep_rew_mean      | -168     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 3459     |
# |    time_elapsed     | 10       |
# |    total timesteps  | 34799    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99       |
# |    ep_rew_mean      | -163     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 3462     |
# |    time_elapsed     | 10       |
# |    total timesteps  | 35062    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.6     |
# |    ep_rew_mean      | -160     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 3466     |
# |    time_elapsed     | 10       |
# |    total timesteps  | 35384    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.8     |
# |    ep_rew_mean      | -162     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 3468     |
# |    time_elapsed     | 10       |
# |    total timesteps  | 35765    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.3     |
# |    ep_rew_mean      | -160     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 3470     |
# |    time_elapsed     | 10       |
# |    total timesteps  | 36179    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.9     |
# |    ep_rew_mean      | -159     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 3473     |
# |    time_elapsed     | 10       |
# |    total timesteps  | 36470    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.7     |
# |    ep_rew_mean      | -158     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 3475     |
# |    time_elapsed     | 10       |
# |    total timesteps  | 36880    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.5     |
# |    ep_rew_mean      | -158     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 3478     |
# |    time_elapsed     | 10       |
# |    total timesteps  | 37215    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.3     |
# |    ep_rew_mean      | -158     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 3481     |
# |    time_elapsed     | 10       |
# |    total timesteps  | 37550    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.8     |
# |    ep_rew_mean      | -165     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 3483     |
# |    time_elapsed     | 10       |
# |    total timesteps  | 37952    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.4     |
# |    ep_rew_mean      | -170     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 3486     |
# |    time_elapsed     | 10       |
# |    total timesteps  | 38335    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.5     |
# |    ep_rew_mean      | -170     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 3487     |
# |    time_elapsed     | 11       |
# |    total timesteps  | 38756    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.2     |
# |    ep_rew_mean      | -168     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 3490     |
# |    time_elapsed     | 11       |
# |    total timesteps  | 39119    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.7     |
# |    ep_rew_mean      | -174     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 3493     |
# |    time_elapsed     | 11       |
# |    total timesteps  | 39502    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.8     |
# |    ep_rew_mean      | -176     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 3496     |
# |    time_elapsed     | 11       |
# |    total timesteps  | 39829    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.7     |
# |    ep_rew_mean      | -180     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 3498     |
# |    time_elapsed     | 11       |
# |    total timesteps  | 40228    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.5     |
# |    ep_rew_mean      | -185     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 3499     |
# |    time_elapsed     | 11       |
# |    total timesteps  | 40587    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92       |
# |    ep_rew_mean      | -181     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 3502     |
# |    time_elapsed     | 11       |
# |    total timesteps  | 40954    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.8     |
# |    ep_rew_mean      | -181     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 3504     |
# |    time_elapsed     | 11       |
# |    total timesteps  | 41338    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.3     |
# |    ep_rew_mean      | -180     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 3506     |
# |    time_elapsed     | 11       |
# |    total timesteps  | 41672    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.9     |
# |    ep_rew_mean      | -177     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 3509     |
# |    time_elapsed     | 11       |
# |    total timesteps  | 42021    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | -175     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 3316     |
# |    time_elapsed     | 13       |
# |    total timesteps  | 43325    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | -176     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 3320     |
# |    time_elapsed     | 13       |
# |    total timesteps  | 43725    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.2     |
# |    ep_rew_mean      | -180     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 3322     |
# |    time_elapsed     | 13       |
# |    total timesteps  | 44040    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99       |
# |    ep_rew_mean      | -181     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 3326     |
# |    time_elapsed     | 13       |
# |    total timesteps  | 44385    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.6     |
# |    ep_rew_mean      | -175     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 3329     |
# |    time_elapsed     | 13       |
# |    total timesteps  | 44758    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | -178     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 476      |
# |    fps              | 3333     |
# |    time_elapsed     | 13       |
# |    total timesteps  | 45149    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | -179     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 3336     |
# |    time_elapsed     | 13       |
# |    total timesteps  | 45480    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | -178     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 484      |
# |    fps              | 3339     |
# |    time_elapsed     | 13       |
# |    total timesteps  | 45853    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | -178     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 488      |
# |    fps              | 3342     |
# |    time_elapsed     | 13       |
# |    total timesteps  | 46194    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | -181     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 492      |
# |    fps              | 3345     |
# |    time_elapsed     | 13       |
# |    total timesteps  | 46603    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | -180     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 496      |
# |    fps              | 3348     |
# |    time_elapsed     | 14       |
# |    total timesteps  | 46914    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | -183     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 500      |
# |    fps              | 3351     |
# |    time_elapsed     | 14       |
# |    total timesteps  | 47262    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | -181     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 504      |
# |    fps              | 3354     |
# |    time_elapsed     | 14       |
# |    total timesteps  | 47626    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | -179     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 508      |
# |    fps              | 3357     |
# |    time_elapsed     | 14       |
# |    total timesteps  | 47958    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.8     |
# |    ep_rew_mean      | -180     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 512      |
# |    fps              | 3360     |
# |    time_elapsed     | 14       |
# |    total timesteps  | 48319    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.4     |
# |    ep_rew_mean      | -179     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 516      |
# |    fps              | 3362     |
# |    time_elapsed     | 14       |
# |    total timesteps  | 48696    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99       |
# |    ep_rew_mean      | -178     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 520      |
# |    fps              | 3365     |
# |    time_elapsed     | 14       |
# |    total timesteps  | 49018    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99       |
# |    ep_rew_mean      | -174     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 524      |
# |    fps              | 3367     |
# |    time_elapsed     | 14       |
# |    total timesteps  | 49405    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.2     |
# |    ep_rew_mean      | -175     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 528      |
# |    fps              | 3370     |
# |    time_elapsed     | 14       |
# |    total timesteps  | 49748    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.9     |
# |    ep_rew_mean      | -177     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 532      |
# |    fps              | 3336     |
# |    time_elapsed     | 15       |
# |    total timesteps  | 50119    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.3      |
# |    n_updates        | 29       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.2     |
# |    ep_rew_mean      | -184     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 536      |
# |    fps              | 3255     |
# |    time_elapsed     | 15       |
# |    total timesteps  | 50402    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.15     |
# |    n_updates        | 100      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99       |
# |    ep_rew_mean      | -205     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 540      |
# |    fps              | 3125     |
# |    time_elapsed     | 16       |
# |    total timesteps  | 50857    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.64     |
# |    n_updates        | 214      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.3     |
# |    ep_rew_mean      | -224     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 544      |
# |    fps              | 3026     |
# |    time_elapsed     | 16       |
# |    total timesteps  | 51268    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.76     |
# |    n_updates        | 316      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | -246     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 548      |
# |    fps              | 2907     |
# |    time_elapsed     | 17       |
# |    total timesteps  | 51750    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.85     |
# |    n_updates        | 437      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 102      |
# |    ep_rew_mean      | -263     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 552      |
# |    fps              | 2814     |
# |    time_elapsed     | 18       |
# |    total timesteps  | 52196    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.54     |
# |    n_updates        | 548      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.7     |
# |    ep_rew_mean      | -298     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 556      |
# |    fps              | 2672     |
# |    time_elapsed     | 19       |
# |    total timesteps  | 52890    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.958    |
# |    n_updates        | 722      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.4     |
# |    ep_rew_mean      | -327     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 560      |
# |    fps              | 2555     |
# |    time_elapsed     | 20       |
# |    total timesteps  | 53567    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.67     |
# |    n_updates        | 891      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 104      |
# |    ep_rew_mean      | -342     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 564      |
# |    fps              | 2417     |
# |    time_elapsed     | 22       |
# |    total timesteps  | 54488    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7        |
# |    n_updates        | 1121     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 118      |
# |    ep_rew_mean      | -337     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 568      |
# |    fps              | 2138     |
# |    time_elapsed     | 26       |
# |    total timesteps  | 56189    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.988    |
# |    n_updates        | 1547     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 129      |
# |    ep_rew_mean      | -337     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 572      |
# |    fps              | 1891     |
# |    time_elapsed     | 30       |
# |    total timesteps  | 57692    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.5      |
# |    n_updates        | 1922     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 165      |
# |    ep_rew_mean      | -336     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 576      |
# |    fps              | 1469     |
# |    time_elapsed     | 41       |
# |    total timesteps  | 61692    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.46     |
# |    n_updates        | 2922     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 202      |
# |    ep_rew_mean      | -334     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 580      |
# |    fps              | 1237     |
# |    time_elapsed     | 53       |
# |    total timesteps  | 65692    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.26     |
# |    n_updates        | 3922     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 231      |
# |    ep_rew_mean      | -322     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 584      |
# |    fps              | 1132     |
# |    time_elapsed     | 60       |
# |    total timesteps  | 68963    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.01     |
# |    n_updates        | 4740     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 266      |
# |    ep_rew_mean      | -315     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 588      |
# |    fps              | 1007     |
# |    time_elapsed     | 72       |
# |    total timesteps  | 72779    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.96     |
# |    n_updates        | 5694     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 295      |
# |    ep_rew_mean      | -303     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 592      |
# |    fps              | 939      |
# |    time_elapsed     | 81       |
# |    total timesteps  | 76113    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.17     |
# |    n_updates        | 6528     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 330      |
# |    ep_rew_mean      | -297     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 596      |
# |    fps              | 878      |
# |    time_elapsed     | 91       |
# |    total timesteps  | 79935    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.46     |
# |    n_updates        | 7483     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 360      |
# |    ep_rew_mean      | -289     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 600      |
# |    fps              | 829      |
# |    time_elapsed     | 100      |
# |    total timesteps  | 83257    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.897    |
# |    n_updates        | 8314     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 388      |
# |    ep_rew_mean      | -278     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 604      |
# |    fps              | 798      |
# |    time_elapsed     | 108      |
# |    total timesteps  | 86469    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.1      |
# |    n_updates        | 9117     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 420      |
# |    ep_rew_mean      | -271     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 608      |
# |    fps              | 764      |
# |    time_elapsed     | 117      |
# |    total timesteps  | 89940    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.88     |
# |    n_updates        | 9984     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 447      |
# |    ep_rew_mean      | -264     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 612      |
# |    fps              | 745      |
# |    time_elapsed     | 124      |
# |    total timesteps  | 93020    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.775    |
# |    n_updates        | 10754    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 477      |
# |    ep_rew_mean      | -262     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 616      |
# |    fps              | 720      |
# |    time_elapsed     | 133      |
# |    total timesteps  | 96443    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.18     |
# |    n_updates        | 11610    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 509      |
# |    ep_rew_mean      | -255     |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 620      |
# |    fps              | 702      |
# |    time_elapsed     | 142      |
# |    total timesteps  | 99905    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.84     |
# |    n_updates        | 12476    |
# ----------------------------------

# %% [markdown]
# ## Load the trained agent

# %%
model = DQN.load("dqn_lunar")

# %%
# Evaluate the trained agent
mean_reward, std_reward = evaluate_policy(model, eval_env, n_eval_episodes=10, deterministic=True)

print(f"mean_reward={mean_reward:.2f} +/- {std_reward}")
# Out:
# mean_reward=-78.52 +/- 92.37523123180719
